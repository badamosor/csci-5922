# %%
from __future__ import unicode_literals, print_function, division
from io import open
import unicodedata
import string
import re
import random
import nltk
nltk.download('punkt')


import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Out:
# [nltk_data] Downloading package punkt to /Users/badamosor/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
SOS_token = 0
EOS_token = 1


class Lang:
    def __init__(self, name):
        self.name = name
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2  # Count SOS and EOS
        
    def addSentence(self, sentence):
        
        regex = "[\u0618-\u061A|\u064B-\u0653]"

        tokenized_text = megasplit('', sentence)
        
        chars = []
        
        for i in range(len(tokenized_text)):
            if (tokenized_text[i] == ''):
                continue
            if (re.search(regex, tokenized_text[i])):
                continue
                
            if (re.search(regex, tokenized_text[i+1])):
                char = tokenized_text[i] + tokenized_text[i+1]
                chars.append(char)
                self.addWord(char)
                
            else:
                self.addWord(tokenized_text[i])
                                  
    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
import codecs
import csv
import random
from sklearn.model_selection import train_test_split

def readLangs(lang1, lang2, reverse=False):
    print("Reading lines...")   

    FILENAME_TRAIN = "char_basedTrain.data"
    FILENAME_TEST = "char_basedTest.data"   

    ENCODING = 'utf-8'
    train_pairs = []
    with codecs.open(FILENAME_TRAIN, "r", ENCODING) as fp:
      reader = csv.reader(fp)
      for rows in reader:
        train_pairs.append(rows)
        
    test_pairs = []
    with codecs.open(FILENAME_TEST, "r", ENCODING) as fp:
      reader = csv.reader(fp)
      for rows in reader:
        test_pairs.append(rows)
      
        
    input_lang = Lang(lang1)
    output_lang = Lang(lang2)
    
    return input_lang, output_lang, train_pairs, test_pairs

# %%
def megasplit(pattern, string):
    splits = list((m.start(), m.end()) for m in re.finditer(pattern, string))
    starts = [0] + [i[1] for i in splits]
    ends = [i[0] for i in splits] + [len(string)]
    return [string[start:end] for start, end in zip(starts, ends)]

  
def prepareData(lang1, lang2, reverse=False):
    input_lang, output_lang, train_pairs, test_pairs = readLangs(lang1, lang2, reverse)
  
    print("Read %s training sentence pairs" % len(train_pairs))
    print("Counting words...")
    
    for pair in train_pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    
    ##!!!Adding new words in test to training words
    
    print("Read %s test sentence pairs" % len(test_pairs))
    print("Counting words...")
    for pair in test_pairs:
        input_lang.addSentence(pair[0])
        output_lang.addSentence(pair[1])
    print("Counted words:")
    print(input_lang.name, input_lang.n_words)
    print(output_lang.name, output_lang.n_words)
    
    return input_lang, output_lang, train_pairs, test_pairs


input_lang, output_lang, train_pairs, test_pairs = prepareData('NoDiac', 'Diac', False)
print(random.choice(train_pairs))
print(random.choice(test_pairs))
# Out:
# Reading lines...
# Read 12004 training sentence pairs
# Counting words...
# Counted words:
# NoDiac 39
# Diac 257
': 125, 'ض': 126, 'ؤَ': 127, 'ثٌ': 128, 'دَ': 129, 'جْ': 130, 'خَ': 131, 'ةِ': 132, 'شَ': 133, 'إِ': 134, 'فْ': 135, 'حُ': 136, 'ءِ': 137, 'إ': 138, 'يَ': 139, 'صْ': 140, 'عِ': 141, 'رُ': 142, 'وْ': 143, 'حْ': 144, 'شُ': 145, 'تّ': 146, 'تِ': 147, 'ط': 148, 'وّ': 149, 'صِ': 150, 'هْ': 151, 'ى': 152, 'ث': 153, 'صّ': 154, 'ؤُ': 155, 'ثَ': 156, 'طِ': 157, 'قِ': 158, 'طْ': 159, 'فِ': 160, 'خْ': 161, 'قْ': 162, 'ئ': 163, 'ذُ': 164, 'سٍ': 165, 'ذّ': 166, 'اّ': 167, 'نٌ': 168, 'فّ': 169, 'ةً': 170, 'ئْ': 171, 'ثُ': 172, 'يِ': 173, 'شٌ': 174, 'ةَ': 175, 'ضٌ': 176, 'قٌ': 177, 'لٍ': 178, 'ثّ': 179, 'ظِ': 180, 'مٌ': 181, 'بٍ': 182, 'وِ': 183, 'رٍ': 184, 'هّ': 185, 'سّ': 186, 'ء': 187, 'عٌ': 188, 'ز': 189, 'أْ': 190, 'يٍ': 191, 'أُ': 192, 'غْ': 193, 'ثْ': 194, 'عٍ': 195, 'غ': 196, 'قّ': 197, 'جِ': 198, 'ذٍ': 199, 'صٍ': 200, 'حٍ': 201, 'حٌ': 202, 'تً': 203, 'تٍ': 204, 'ءَ': 205, 'وُ': 206, 'ىْ': 207, 'حّ': 208, 'ضْ': 209, 'دٍ': 210, 'نٍ': 211, 'ةٍ': 212, 'ءٍ': 213, 'مٍ': 214, 'ظْ': 215, 'ظَ': 216, 'خّ': 217, 'وٌ': 218, 'زُ': 219, 'طٌ': 220, 'ذِ': 221, 'زٍ': 222, 'فٌ': 223, 'غِ': 224, 'ظُ': 225, 'شٍ': 226, 'ضٍ': 227, 'ثِ': 228, 'نً': 229, 'ئُ': 230, 'وٍ': 231, 'ءٌ': 232, 'فٍ': 233, 'زٌ': 234, 'ئٌ': 235, 'كٌ': 236, 'ءً': 237, 'طً': 238, 'كٍ': 239, 'طٍ': 240, 'ىّ': 241, 'ىً': 242, 'عّ': 243, 'زً': 244, 'أِ': 245, 'جٍ': 246, 'ئَ': 247, 'قٍ': 248, 'ئٍ': 249, 'هٍ': 250, 'هٌ': 251, 'ظّ': 252, 'ؤٌ': 253, 'أً': 254, 'جٌ': 255, 'ثٍ': 256}]

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, hidden_size):
        super(EncoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(input_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)

    def forward(self, input, hidden):
        embedded = self.embedding(input).view(1, 1, -1)
        output = embedded
        output, hidden = self.gru(output, hidden)
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
class DecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size):
        super(DecoderRNN, self).__init__()
        self.hidden_size = hidden_size

        self.embedding = nn.Embedding(output_size, hidden_size)
        self.gru = nn.GRU(hidden_size, hidden_size)
        self.out = nn.Linear(hidden_size, output_size)
        self.softmax = nn.LogSoftmax(dim=1)

    def forward(self, input, hidden):
        output = self.embedding(input).view(1, 1, -1)
        output = F.relu(output)
        output, hidden = self.gru(output, hidden)
        output = self.softmax(self.out(output[0]))
        return output, hidden

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
MAX_LENGTH = 50

# %%
class AttnDecoderRNN(nn.Module):
    def __init__(self, hidden_size, output_size, dropout_p=0.1, max_length=MAX_LENGTH):
        super(AttnDecoderRNN, self).__init__()
        self.hidden_size = hidden_size
        self.output_size = output_size
        self.dropout_p = dropout_p
        self.max_length = max_length

        self.embedding = nn.Embedding(self.output_size, self.hidden_size)
        self.attn = nn.Linear(self.hidden_size * 2, self.max_length)
        self.attn_combine = nn.Linear(self.hidden_size * 2, self.hidden_size)
        self.dropout = nn.Dropout(self.dropout_p)
        self.gru = nn.GRU(self.hidden_size, self.hidden_size)
        self.out = nn.Linear(self.hidden_size, self.output_size)

    def forward(self, input, hidden, encoder_outputs):
        embedded = self.embedding(input).view(1, 1, -1)
        embedded = self.dropout(embedded)

        attn_weights = F.softmax(
            self.attn(torch.cat((embedded[0], hidden[0]), 1)), dim=1)
        attn_applied = torch.bmm(attn_weights.unsqueeze(0),
                                 encoder_outputs.unsqueeze(0))

        output = torch.cat((embedded[0], attn_applied[0]), 1)
        output = self.attn_combine(output).unsqueeze(0)

        output = F.relu(output)
        output, hidden = self.gru(output, hidden)

        output = F.log_softmax(self.out(output[0]), dim=1)
        return output, hidden, attn_weights

    def initHidden(self):
        return torch.zeros(1, 1, self.hidden_size, device=device)

# %%
def indexesFromSentence(lang, sentence):
    regex = "[\u0618-\u061A|\u064B-\u0653]"
    tokenized_text = megasplit('', sentence)
        
    chars = []
        
    for i in range(len(tokenized_text)):
        if (tokenized_text[i] == ''):
            continue
        if (re.search(regex, tokenized_text[i])):
            continue
                
        if (re.search(regex, tokenized_text[i+1])):
            char = tokenized_text[i] + tokenized_text[i+1]
            chars.append(lang.word2index[char])                
        else:
            chars.append(lang.word2index[tokenized_text[i]])

    return chars

def tensorFromSentence(lang, sentence):
    indexes = indexesFromSentence(lang, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromSentence(input_lang, pair[0])
    target_tensor = tensorFromSentence(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %%
teacher_forcing_ratio = 0.5


def train(input_tensor, target_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)

    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

    loss = 0

    for ei in range(input_length):
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
        encoder_outputs[ei] = encoder_output[0, 0]

    decoder_input = torch.tensor([[SOS_token]], device=device)

    decoder_hidden = encoder_hidden

    #use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False
    use_teacher_forcing = False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        for di in range(target_length):
            #decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
            loss += criterion(decoder_output, target_tensor[di])
            decoder_input = target_tensor[di]  # Teacher forcing

    else:
        # Without teacher forcing: use its own predictions as the next input
        for di in range(target_length):
            #decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()  # detach from history as input

            loss += criterion(decoder_output, target_tensor[di])
            if decoder_input.item() == EOS_token:
                break

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
import time
import math


def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %%
averageLoss = []
accuracies = []

# %%
lr_per_iter = []


def trainIters(encoder, decoder, n_iters, print_every=1000, plot_every=100, learning_rate=0.01):
    start = time.time()
    plot_losses = []
    print_loss_total = 0  # Reset every print_every
    plot_loss_total = 0  # Reset every plot_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)
    #training_pairs = [tensorsFromPair(random.choice(pairs)) for i in range(n_iters)]
    #training_pairs = [tensorsFromPair(random.choice(train_pairs)) for i in range(n_iters)]
    
    criterion = nn.NLLLoss()
        
    for i in range(n_iters):
        print(i)
        numExample = 0
        for pairs in train_pairs:
            training_pair = tensorsFromPair(pairs)
            input_tensor = training_pair[0]
            target_tensor = training_pair[1]
            
            loss = train(input_tensor, target_tensor, encoder,decoder, encoder_optimizer, decoder_optimizer, criterion)
            print_loss_total += loss
            plot_loss_total += loss
            numExample += 1
            
            if (numExample % print_every == 0):
                print_loss_avg = print_loss_total / print_every
                print_loss_total = 0
                #print('%s (%d %d%%) %.4f' % (timeSince(start, iter / n_iters),
                                         #iter, iter / n_iters * 100, print_loss_avg))
                print('%s %d %.4f %d' % (timeSince(start, numExample), numExample, print_loss_avg, i))
      
        accuracy = getAccuracy(encoder1, decoder)
        accuracies.append(accuracy)
        averageLoss.append(print_loss_total / print_every)
        print(('%.4f,%.4f') % ((print_loss_total / print_every),loss))
        print(accuracy)

# %% [markdown]
# Evaluation
# ==========

# %%
def evaluate(encoder, decoder, sentence, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromSentence(input_lang, sentence)
        input_length = input_tensor.size()[0]
        encoder_hidden = encoder.initHidden()

        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)

        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        decoder_input = torch.tensor([[SOS_token]], device=device)  # SOS

        decoder_hidden = encoder_hidden

        decoded_words = []
        decoder_attentions = torch.zeros(max_length, max_length)

        for di in range(max_length):
           # decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
           # decoder_attentions[di] = decoder_attention.data
            decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden)            
            topv, topi = decoder_output.data.topk(1)
            if topi.item() == EOS_token:
                #decoded_words.append('<EOS>')
                break
            else:
                #if (topi.item() not in output_lang.test_index2word):
                  #decoded_words.append("unk")
                #else:
                decoded_words.append(output_lang.index2word[topi.item()])

            decoder_input = topi.squeeze().detach()

        #return decoded_words, decoder_attentions[:di + 1]
        return decoded_words

# %%
def getAccuracy(encoder, decoder, n=10):
    
    correct_sentence_pair = 0
    incorrect_sentence_pair = 0
    
    correct_word_pair = 0
    incorrect_word_pair = 0
        
    correct_diac = 0
    incorrect_diac = 0
    
    regex = "[\u0618-\u061A|\u064B-\u0653]"
 
    count = 0
    sentenceInput = []
    sentenceTarget = []
    sentenceOutput = []
    
    for pair in test_pairs:
        
        output_chars = evaluate(encoder, decoder, pair[0])
        output_word = ''.join(output_chars)
            
        if(count < 4):
            sentenceInput.append(pair[0])
            sentenceTarget.append(pair[1])
            sentenceOutput.append(output_word)
            count += 1
        else:
            #Accuracy on sentence basis
            
            if (sentenceTarget == sentenceOutput):
                correct_sentence_pair += 1
                #print('correct: ',sentenceTarget, sentenceOutput)

            else:
                incorrect_sentence_pair += 1
                #print('incorrect: ',sentenceTarget, sentenceOutput)

            sentenceInput = []
            sentenceTarget = []
            sentenceOutput = [] 
            
            sentenceInput.append(pair[0])
            sentenceTarget.append(pair[1])
            sentenceOutput.append(output_word)
            count = 1            
            
        
        #Accuracy on word basis
        if (pair[1] == output_word):
            if (re.search(regex, pair[1])):
                correct_diac += 1
                correct_word_pair += 1
        else:
            if (re.search(regex, pair[1])):
                incorrect_diac += 1
                incorrect_word_pair += 1     
  
    return((correct_word_pair/(correct_word_pair+incorrect_word_pair), correct_sentence_pair/(correct_sentence_pair+incorrect_sentence_pair)))

# %%
def evaluateRandomly(encoder, decoder, n=10):
    
    correct_sentence_pair = 0
    incorrect_sentence_pair = 0
    
    correct_word_pair = 0
    incorrect_word_pair = 0
        
    correct_diac = 0
    incorrect_diac = 0
    
    regex = "[\u0618-\u061A|\u064B-\u0653]"
 
    count = 0
    sentenceInput = []
    sentenceTarget = []
    sentenceOutput = []
    
    for pair in test_pairs:
                    
        output_chars = evaluate(encoder, decoder, pair[0])
        output_word = ''.join(output_chars)
            
        if(count < 4):
            sentenceInput.append(pair[0])
            sentenceTarget.append(pair[1])
            sentenceOutput.append(output_word)
            count += 1
        else:
            #Accuracy on sentence basis
            
            if (sentenceTarget == sentenceOutput):
                correct_sentence_pair += 1
                print('correct: ',sentenceTarget, sentenceOutput)


            else:
                incorrect_sentence_pair += 1
                print('incorrect: ',sentenceTarget, sentenceOutput)

            sentenceInput = []
            sentenceTarget = []
            sentenceOutput = [] 
            
            sentenceInput.append(pair[0])
            sentenceTarget.append(pair[1])
            sentenceOutput.append(output_word)
            count = 1            
            
        
        #Accuracy on word basis
        if (pair[1] == output_word):
            if (re.search(regex, pair[1])):
                correct_diac += 1
                correct_word_pair += 1
        else:
            if (re.search(regex, pair[1])):
                incorrect_diac += 1
                incorrect_word_pair += 1     
  
    print("accuracy of words:",correct_word_pair/(correct_word_pair+incorrect_word_pair),correct_word_pair,incorrect_word_pair) 
    print("percentage correct diacritic:",correct_diac/correct_word_pair)
    print("Number of all words: ",correct_word_pair+correct_word_pair)
    
    print("accuracy of sentence:",correct_sentence_pair/(correct_sentence_pair+incorrect_sentence_pair),correct_sentence_pair,incorrect_sentence_pair) 
    print("Number of all sentences: ", correct_sentence_pair+incorrect_sentence_pair)

# %%
print("input:", input_lang.n_words)
print("train size", len(train_pairs))
# Out:
# input: 39
# train size 12004

# %%
hidden_size = 256

encoder1 = EncoderRNN(input_lang.n_words, hidden_size).to(device)
#attn_decoder1 = AttnDecoderRNN(hidden_size, output_lang.n_words, dropout_p=0.1).to(device)
decoder1 = DecoderRNN(hidden_size, output_lang.n_words).to(device)
#print("Embeddings:", encoder1.embedding)

#trainIters(encoder1, attn_decoder1, 100, print_every=500)
#trainIters(encoder1, decoder1, 1000, print_every=500)
trainIters(encoder1, decoder1, 100, print_every=1000)
# Out:
# 0
# 0m 17s (- -1m 42s) 1000 2.8476 0
# 0m 36s (- -1m 23s) 2000 2.7635 0
# 0m 55s (- -1m 4s) 3000 2.3606 0
# 1m 16s (- -2m 43s) 4000 2.2564 0
# 1m 36s (- -2m 23s) 5000 1.9955 0
# 1m 56s (- -2m 3s) 6000 1.9438 0
# 2m 16s (- -3m 43s) 7000 1.8275 0
# 2m 37s (- -3m 22s) 8000 1.6953 0
# 2m 58s (- -3m 1s) 9000 1.5690 0
# 3m 20s (- -4m 39s) 10000 1.5394 0
# 3m 40s (- -4m 19s) 11000 1.4749 0
# 4m 1s (- -5m 58s) 12000 1.3835 0
# 0.0046,2.2705
# (0.10880458124552612, 0.0)
# 1
# 4m 27s (- -5m 32s) 1000 1.5295 1
# 4m 48s (- -5m 11s) 2000 1.3457 1
# 5m 8s (- -6m 51s) 3000 1.1750 1
# 5m 29s (- -6m 30s) 4000 1.2420 1
# 5m 50s (- -6m 9s) 5000 1.1265 1
# 6m 11s (- -7m 48s) 6000 1.1746 1
# 6m 32s (- -7m 27s) 7000 1.1374 1
# 6m 53s (- -7m 6s) 8000 1.1065 1
# 7m 14s (- -8m 45s) 9000 1.0392 1
# 7m 34s (- -8m 25s) 10000 1.0838 1
# 7m 55s (- -8m 4s) 11000 1.0257 1
# 8m 16s (- -9m 43s) 12000 0.9993 1
# 0.0034,1.6693
# (0.14387974230493916, 0.0)
# 2
# 8m 42s (- -9m 17s) 1000 1.1292 2
# 9m 3s (- -10m 56s) 2000 0.9864 2
# 9m 24s (- -10m 35s) 3000 0.8898 2
# 9m 45s (- -10m 14s) 4000 0.9834 2
# 10m 5s (- -11m 54s) 5000 0.8695 2
# 10m 27s (- -11m 32s) 6000 0.9413 2
# 10m 47s (- -11m 12s) 7000 0.9221 2
# 11m 8s (- -12m 51s) 8000 0.8977 2
# 11m 30s (- -12m 30s) 9000 0.8559 2
# 11m 50s (- -12m 9s) 10000 0.9138 2
# 12m 11s (- -13m 49s) 11000 0.8548 2
# 12m 32s (- -13m 28s) 12000 0.8353 2
# 0.0030,1.6015
# (0.16678596993557623, 0.01179245283018868)
# 3
# 12m 59s (- -13m 1s) 1000 0.9765 3
# 13m 19s (- -14m 40s) 2000 0.8594 3
# 13m 40s (- -14m 19s) 3000 0.7597 3
# 14m 1s (- -15m 59s) 4000 0.8251 3
# 14m 22s (- -15m 38s) 5000 0.7745 3
# 14m 43s (- -15m 16s) 6000 0.8183 3
# 15m 3s (- -16m 56s) 7000 0.8194 3
# 15m 24s (- -16m 35s) 8000 0.7744 3
# 15m 45s (- -16m 14s) 9000 0.7441 3
# 16m 7s (- -17m 52s) 10000 0.8061 3
# 16m 30s (- -17m 29s) 11000 0.7688 3
# 16m 51s (- -17m 8s) 12000 0.7548 3
# 0.0029,1.6782
# (0.19040801717967074, 0.009433962264150943)
# 4
# 17m 18s (- -18m 42s) 1000 0.8591 4
# 17m 39s (- -18m 20s) 2000 0.7661 4
# 18m 0s (- -19m 59s) 3000 0.6638 4
# 18m 21s (- -19m 38s) 4000 0.7669 4
# 18m 42s (- -19m 17s) 5000 0.6860 4
# 19m 4s (- -20m 56s) 6000 0.7194 4
# 19m 24s (- -20m 35s) 7000 0.7360 4
# 19m 45s (- -20m 14s) 8000 0.7158 4
# 20m 7s (- -21m 53s) 9000 0.6911 4
# 20m 27s (- -21m 32s) 10000 0.7326 4
# 20m 48s (- -21m 11s) 11000 0.6836 4
# 21m 9s (- -22m 50s) 12000 0.6654 4
# 0.0026,1.1997
# (0.19756621331424482, 0.01179245283018868)
# 5
# 21m 36s (- -22m 24s) 1000 0.7821 5
# 21m 58s (- -22m 2s) 2000 0.6856 5
# 22m 18s (- -23m 41s) 3000 0.6137 5
# 22m 39s (- -23m 20s) 4000 0.7104 5
# 23m 0s (- -24m 59s) 5000 0.6384 5
# 23m 21s (- -24m 38s) 6000 0.6655 5
# 23m 41s (- -24m 18s) 7000 0.6719 5
# 24m 3s (- -25m 57s) 8000 0.6626 5
# 24m 24s (- -25m 35s) 9000 0.6648 5
# 24m 44s (- -25m 15s) 10000 0.6886 5
# 25m 5s (- -26m 54s) 11000 0.6442 5
# 25m 26s (- -26m 33s) 12000 0.6157 5
# 0.0024,1.4496
# (0.2125984251968504, 0.01179245283018868)
# 6
# 25m 53s (- -26m 8s) 1000 0.7002 6
# 26m 14s (- -27m 46s) 2000 0.6206 6
# 26m 35s (- -27m 25s) 3000 0.5937 6
# 44m 48s (- -45m 12s) 6000 0.4921 10
# 45m 8s (- -46m 51s) 7000 0.5003 10
# 45m 29s (- -46m 30s) 8000 0.4559 10
# 45m 51s (- -46m 9s) 9000 0.4683 10
# 46m 11s (- -47m 48s) 10000 0.4872 10
# 46m 32s (- -47m 27s) 11000 0.4650 10
# 46m 53s (- -47m 6s) 12000 0.4590 10
# 0.0013,0.7252
# (0.2612741589119542, 0.018867924528301886)
# 11
# 47m 21s (- -48m 41s) 1000 0.4989 11
# 47m 42s (- -48m 18s) 2000 0.4560 11
# 48m 3s (- -49m 57s) 3000 0.4270 11
# 48m 24s (- -49m 36s) 4000 0.4937 11
# 48m 45s (- -49m 15s) 5000 0.4373 11
# 49m 6s (- -50m 54s) 6000 0.4592 11
# 49m 26s (- -50m 33s) 7000 0.4825 11
# 49m 47s (- -50m 12s) 8000 0.4561 11
# 50m 9s (- -51m 51s) 9000 0.4649 11
# 50m 29s (- -51m 30s) 10000 0.4598 11
# 50m 50s (- -51m 9s) 11000 0.4183 11
# 51m 11s (- -52m 48s) 12000 0.4172 11
# 0.0018,0.9690
# (0.2634216177523264, 0.014150943396226415)
# 12
# 51m 38s (- -52m 24s) 1000 0.4660 12
# 51m 59s (- -52m 2s) 2000 0.4153 12
# 52m 20s (- -53m 41s) 3000 0.3748 12
# 52m 40s (- -53m 20s) 4000 0.4898 12
# 53m 1s (- -54m 58s) 5000 0.4195 12
# 53m 23s (- -54m 37s) 6000 0.4311 12
# 53m 43s (- -54m 17s) 7000 0.4534 12
# 54m 4s (- -55m 55s) 8000 0.4338 12
# 54m 26s (- -55m 34s) 9000 0.4398 12
# 54m 46s (- -55m 13s) 10000 0.4454 12
# 55m 7s (- -56m 53s) 11000 0.3951 12
# 55m 28s (- -56m 31s) 12000 0.4030 12
# 0.0008,0.3502
# (0.2691481746599857, 0.01650943396226415)
# 13
# 55m 55s (- -56m 7s) 1000 0.4592 13
# 56m 16s (- -57m 45s) 2000 0.4381 13
# 56m 37s (- -57m 23s) 3000 0.3723 13
# 56m 57s (- -57m 2s) 4000 0.4781 13
# 57m 18s (- -58m 42s) 5000 0.4194 13
# 57m 39s (- -58m 20s) 6000 0.4455 13
# 58m 0s (- -59m 59s) 7000 0.4238 13
# 58m 21s (- -59m 38s) 8000 0.4272 13
# 58m 43s (- -59m 17s) 9000 0.4141 13
# 59m 3s (- -60m 56s) 10000 0.4283 13
# 59m 24s (- -60m 35s) 11000 0.3945 13
# 59m 45s (- -60m 15s) 12000 0.3801 13
# 0.0007,0.3443
# (0.27415891195418757, 0.02122641509433962)
# 14
# 60m 11s (- -61m 51s) 1000 0.4387 14
# 60m 33s (- -61m 28s) 2000 0.4025 14
# 60m 54s (- -61m 7s) 3000 0.3651 14
# 61m 15s (- -62m 45s) 4000 0.4319 14
# 61m 36s (- -62m 24s) 5000 0.4150 14
# 61m 57s (- -62m 3s) 6000 0.4339 14
# 62m 17s (- -63m 43s) 7000 0.4102 14
# 62m 39s (- -63m 21s) 8000 0.3968 14
# (0.427344309234073, 0.07783018867924528)
# 40
# 171m 56s (- -172m 13s) 1000 0.1913 40
# 172m 18s (- -173m 46s) 2000 0.1620 40
# 172m 39s (- -173m 24s) 3000 0.1527 40
# 173m 0s (- -173m 2s) 4000 0.1830 40
# 173m 20s (- -174m 41s) 5000 0.1886 40
# 173m 42s (- -174m 19s) 6000 0.2037 40
# 174m 2s (- -175m 58s) 7000 0.1842 40
# 174m 24s (- -175m 36s) 8000 0.1653 40
# 174m 45s (- -175m 15s) 9000 0.1551 40
# 175m 6s (- -176m 54s) 10000 0.1953 40
# 175m 27s (- -176m 33s) 11000 0.1444 40
# 175m 48s (- -176m 12s) 12000 0.1587 40
# 0.0001,0.0643
# (0.4266284896206156, 0.08018867924528301)
# 41
# 176m 15s (- -177m 55s) 1000 0.1858 41
# 176m 36s (- -177m 28s) 2000 0.1579 41
# 176m 57s (- -177m 6s) 3000 0.1457 41
# 177m 18s (- -178m 44s) 4000 0.1845 41
# 177m 38s (- -178m 23s) 5000 0.1838 41
# 178m 0s (- -178m 1s) 6000 0.1930 41
# 178m 20s (- -179m 41s) 7000 0.1746 41
# 178m 41s (- -179m 19s) 8000 0.1625 41
# 179m 3s (- -180m 58s) 9000 0.1450 41
# 179m 23s (- -180m 37s) 10000 0.1801 41
# 179m 44s (- -180m 16s) 11000 0.1399 41
# 180m 5s (- -181m 55s) 12000 0.1519 41
# 0.0001,0.0235
# (0.4280601288475304, 0.07783018867924528)
# 42
# 180m 32s (- -181m 38s) 1000 0.1786 42
# 180m 53s (- -181m 11s) 2000 0.1505 42
# 181m 14s (- -182m 48s) 3000 0.1430 42
# 181m 35s (- -182m 26s) 4000 0.1822 42
# 181m 56s (- -182m 5s) 5000 0.1795 42
# 182m 18s (- -183m 43s) 6000 0.1937 42
# 182m 38s (- -183m 22s) 7000 0.1716 42
# 183m 0s (- -183m 1s) 8000 0.1559 42
# 183m 21s (- -184m 39s) 9000 0.1401 42
# 183m 41s (- -184m 19s) 10000 0.1778 42
# 184m 2s (- -185m 58s) 11000 0.1351 42
# 184m 24s (- -185m 36s) 12000 0.1577 42
# 0.0001,0.0210
# (0.4323550465282749, 0.08490566037735849)
# 43
# 184m 51s (- -185m 19s) 1000 0.1676 43
# 185m 12s (- -186m 53s) 2000 0.1481 43
# 185m 33s (- -186m 30s) 3000 0.1414 43
# 185m 54s (- -186m 8s) 4000 0.1794 43
# 186m 14s (- -187m 47s) 5000 0.1792 43
# 186m 36s (- -187m 25s) 6000 0.1930 43
# 186m 58s (- -187m 3s) 7000 0.1657 43
# 187m 19s (- -188m 41s) 8000 0.1489 43
# 187m 40s (- -188m 20s) 9000 0.1397 43
# 188m 1s (- -189m 59s) 10000 0.1679 43
# 188m 23s (- -189m 37s) 11000 0.1362 43
# 188m 44s (- -189m 16s) 12000 0.1479 43
# 0.0001,0.0270
# (0.4330708661417323, 0.08254716981132075)
# 44
# 189m 11s (- -190m 59s) 1000 0.1716 44
# 189m 32s (- -190m 33s) 2000 0.1446 44
# 244m 41s (- -245m 19s) 12000 0.1374 56
# 0.0001,0.0271
# (0.44667143879742305, 0.08726415094339622)
# 57
# 245m 8s (- -245m 5s) 1000 0.1617 57
# 245m 30s (- -246m 37s) 2000 0.1314 57
# 245m 50s (- -246m 13s) 3000 0.1332 57
# 246m 11s (- -247m 51s) 4000 0.1588 57
# 246m 32s (- -247m 30s) 5000 0.1689 57
# 246m 53s (- -247m 8s) 6000 0.1831 57
# 247m 14s (- -248m 47s) 7000 0.1592 57
# 247m 36s (- -248m 25s) 8000 0.1401 57
# 247m 57s (- -248m 3s) 9000 0.1354 57
# 248m 18s (- -249m 43s) 10000 0.1590 57
# 248m 39s (- -249m 22s) 11000 0.1324 57
# 249m 0s (- -249m 1s) 12000 0.1421 57
# 0.0001,0.0259
# (0.4523979957050823, 0.08962264150943396)
# 58
# 249m 27s (- -250m 47s) 1000 0.1669 58
# 249m 48s (- -250m 19s) 2000 0.1433 58
# 250m 9s (- -251m 55s) 3000 0.1324 58
# 250m 29s (- -251m 33s) 4000 0.1607 58
# 250m 50s (- -251m 12s) 5000 0.1681 58
# 251m 12s (- -252m 50s) 6000 0.1881 58
# 251m 33s (- -252m 28s) 7000 0.1605 58
# 251m 54s (- -252m 6s) 8000 0.1411 58
# 252m 16s (- -253m 45s) 9000 0.1333 58
# 252m 36s (- -253m 24s) 10000 0.1493 58
# 252m 57s (- -253m 3s) 11000 0.1279 58
# 253m 18s (- -254m 42s) 12000 0.1361 58
# 0.0001,0.0278
# (0.44452397995705084, 0.07783018867924528)
# 59
# 253m 45s (- -254m 29s) 1000 0.1596 59
# 254m 6s (- -254m 0s) 2000 0.1369 59
# 254m 27s (- -255m 37s) 3000 0.1382 59
# 254m 48s (- -255m 15s) 4000 0.1565 59
# 255m 9s (- -256m 54s) 5000 0.1711 59
# 255m 30s (- -256m 32s) 6000 0.1774 59
# 255m 50s (- -256m 11s) 7000 0.1560 59
# 256m 12s (- -257m 49s) 8000 0.1356 59
# 256m 33s (- -257m 28s) 9000 0.1368 59
# 256m 54s (- -257m 7s) 10000 0.1541 59
# 257m 15s (- -258m 46s) 11000 0.1242 59
# 257m 36s (- -258m 25s) 12000 0.1382 59
# 0.0000,0.0047
# (0.44738725841088045, 0.08962264150943396)
# 60
# 258m 3s (- -258m 11s) 1000 0.1656 60
# 258m 25s (- -259m 42s) 2000 0.1420 60
# 258m 46s (- -259m 19s) 3000 0.1349 60
# 259m 6s (- -260m 56s) 4000 0.1572 60
# 259m 27s (- -260m 35s) 5000 0.1663 60
# 259m 49s (- -260m 13s) 6000 0.1763 60
# 260m 9s (- -261m 52s) 7000 0.1520 60
# 260m 30s (- -261m 31s) 8000 0.1352 60
# 260m 52s (- -261m 9s) 9000 0.1345 60
# 261m 12s (- -262m 48s) 10000 0.1535 60
# 261m 33s (- -262m 27s) 11000 0.1268 60
# 261m 54s (- -262m 6s) 12000 0.1360 60
# 0.0000,0.0092
# (0.44667143879742305, 0.07783018867924528)
# 61
# 262m 21s (- -263m 54s) 1000 0.1592 61
# 262m 42s (- -263m 25s) 2000 0.1323 61
# 263m 3s (- -263m 1s) 3000 0.1351 61
# 263m 24s (- -264m 39s) 4000 0.1593 61
# 263m 46s (- -264m 17s) 5000 0.1646 61
# 264m 7s (- -265m 55s) 6000 0.1797 61
# 264m 28s (- -265m 34s) 7000 0.1571 61
# 264m 49s (- -265m 12s) 8000 0.1353 61
# 265m 11s (- -266m 50s) 9000 0.1341 61
# 265m 31s (- -266m 29s) 10000 0.1565 61
# 265m 52s (- -266m 9s) 11000 0.1211 61
# 266m 13s (- -267m 48s) 12000 0.1345 61
# 0.0000,0.0106
# (0.44452397995705084, 0.07783018867924528)
# 62
# 266m 40s (- -267m 35s) 1000 0.1516 62
# 267m 1s (- -267m 6s) 2000 0.1411 62
# 267m 22s (- -268m 43s) 3000 0.1336 62
# 267m 42s (- -268m 21s) 4000 0.1561 62
# 268m 3s (- -269m 59s) 5000 0.1625 62
# 268m 25s (- -269m 37s) 6000 0.1772 62
# 268m 45s (- -269m 16s) 7000 0.1528 62
# 269m 7s (- -270m 54s) 8000 0.1352 62
# 269m 29s (- -270m 32s) 9000 0.1349 62
# 269m 49s (- -270m 12s) 10000 0.1540 62
# 270m 10s (- -271m 51s) 11000 0.1239 62
# 270m 31s (- -271m 29s) 12000 0.1389 62
# 0.0000,0.0065
# (0.44881889763779526, 0.08254716981132075)
# 63
# 270m 58s (- -271m 17s) 1000 0.1500 63
# 271m 19s (- -272m 48s) 2000 0.1373 63
# 271m 40s (- -272m 25s) 3000 0.1357 63
# 272m 1s (- -272m 2s) 4000 0.1550 63
# 272m 21s (- -273m 41s) 5000 0.1632 63
# 272m 43s (- -273m 19s) 6000 0.1879 63
# 273m 3s (- -274m 58s) 7000 0.1546 63
# 273m 25s (- -274m 36s) 8000 0.1400 63
# 273m 46s (- -274m 15s) 9000 0.1422 63
# 274m 6s (- -275m 54s) 10000 0.1490 63
# 274m 27s (- -275m 33s) 11000 0.1260 63
# 274m 48s (- -275m 12s) 12000 0.1356 63
# 0.0000,0.0083
# (0.44595561918396565, 0.07783018867924528)
# 64
# 275m 15s (- -275m 0s) 1000 0.1588 64
# 275m 37s (- -276m 31s) 2000 0.1320 64
# 275m 57s (- -276m 7s) 3000 0.1324 64
# 276m 18s (- -277m 45s) 4000 0.1572 64
# 276m 39s (- -277m 23s) 5000 0.1620 64
# 277m 1s (- -277m 1s) 6000 0.1861 64
# 277m 21s (- -278m 40s) 7000 0.1509 64
# 277m 43s (- -278m 18s) 8000 0.1375 64
# 278m 4s (- -279m 57s) 9000 0.1351 64
# 278m 25s (- -279m 36s) 10000 0.1541 64
# 278m 46s (- -279m 15s) 11000 0.1226 64
# 279m 6s (- -280m 54s) 12000 0.1339 64
# 0.0000,0.0101
# (0.4523979957050823, 0.07783018867924528)
# 65
# 279m 33s (- -280m 43s) 1000 0.1572 65
# 279m 54s (- -280m 13s) 2000 0.1315 65
# 280m 15s (- -281m 50s) 3000 0.1328 65
# 280m 36s (- -281m 27s) 4000 0.1626 65
# 280m 57s (- -281m 5s) 5000 0.1652 65
# 281m 18s (- -282m 44s) 6000 0.1892 65
# 281m 39s (- -282m 22s) 7000 0.1529 65
# 282m 0s (- -282m 1s) 8000 0.1386 65
# 282m 22s (- -283m 39s) 9000 0.1345 65
# 282m 42s (- -283m 18s) 10000 0.1608 65
# 283m 4s (- -284m 57s) 11000 0.1226 65
# 283m 24s (- -284m 36s) 12000 0.1394 65
# 0.0000,0.0146
# (0.44738725841088045, 0.07311320754716981)
# 66
# 283m 51s (- -284m 25s) 1000 0.1579 66
# 284m 13s (- -285m 55s) 2000 0.1374 66
# 284m 34s (- -285m 31s) 3000 0.1322 66
# 284m 54s (- -285m 9s) 4000 0.1637 66
# 285m 15s (- -286m 47s) 5000 0.1651 66
# 285m 36s (- -286m 26s) 6000 0.1899 66
# 285m 57s (- -286m 4s) 7000 0.1551 66
# 286m 19s (- -287m 42s) 8000 0.1404 66
# 286m 40s (- -287m 21s) 9000 0.1287 66
# 287m 0s (- -287m 0s) 10000 0.1572 66
# 287m 21s (- -288m 39s) 11000 0.1221 66
# 287m 42s (- -288m 18s) 12000 0.1380 66
# 0.0000,0.0171
# (0.4502505368647101, 0.08018867924528301)
# 67
# 288m 9s (- -288m 7s) 1000 0.1574 67
# 288m 30s (- -289m 37s) 2000 0.1408 67
# 288m 51s (- -289m 14s) 3000 0.1309 67
# 289m 12s (- -290m 51s) 4000 0.1629 67
# 289m 33s (- -290m 30s) 5000 0.1660 67
# 289m 54s (- -290m 8s) 6000 0.1919 67
# 290m 15s (- -291m 47s) 7000 0.1532 67
# 290m 36s (- -291m 25s) 8000 0.1362 67
# 290m 57s (- -291m 4s) 9000 0.1349 67
# 291m 18s (- -292m 43s) 10000 0.1529 67
# 291m 38s (- -292m 22s) 11000 0.1209 67
# 291m 59s (- -292m 1s) 12000 0.1387 67
# 0.0000,0.0060
# (0.4523979957050823, 0.08962264150943396)
# 68
# 292m 26s (- -293m 50s) 1000 0.1507 68
# 292m 48s (- -293m 20s) 2000 0.1327 68
# 293m 8s (- -294m 57s) 3000 0.1329 68
# 293m 29s (- -294m 34s) 4000 0.1626 68
# 293m 50s (- -294m 13s) 5000 0.1728 68
# 294m 11s (- -295m 51s) 6000 0.1980 68
# 294m 31s (- -295m 30s) 7000 0.1584 68
# 294m 53s (- -295m 9s) 8000 0.1355 68
# 295m 14s (- -296m 47s) 9000 0.1312 68
# 295m 34s (- -296m 26s) 10000 0.1504 68
# 295m 55s (- -296m 6s) 11000 0.1272 68
# 296m 16s (- -297m 44s) 12000 0.1384 68
# 0.0000,0.0068
# (0.4595561918396564, 0.08490566037735849)
# 69
# 296m 43s (- -297m 34s) 1000 0.1590 69
# 297m 5s (- -297m 3s) 2000 0.1339 69
# 297m 25s (- -298m 40s) 3000 0.1340 69
# 297m 46s (- -298m 17s) 4000 0.1631 69
# 298m 7s (- -299m 55s) 5000 0.1755 69
# 298m 29s (- -299m 33s) 6000 0.1978 69
# 407m 59s (- -408m 2s) 11000 0.1945 94
# 408m 19s (- -409m 42s) 12000 0.2094 94
# 0.0001,0.0399
# (0.44810307802433785, 0.08018867924528301)
# 95
# 408m 46s (- -409m 37s) 1000 0.2456 95
# 409m 7s (- -409m 4s) 2000 0.2114 95
# 409m 28s (- -410m 39s) 3000 0.2014 95
# 409m 49s (- -410m 16s) 4000 0.2466 95
# 410m 10s (- -411m 54s) 5000 0.2164 95
# 410m 31s (- -411m 32s) 6000 0.2459 95
# 410m 52s (- -411m 11s) 7000 0.2298 95
# 411m 13s (- -412m 49s) 8000 0.2080 95
# 411m 34s (- -412m 27s) 9000 0.1980 95
# 411m 55s (- -412m 7s) 10000 0.2002 95
# 412m 16s (- -413m 45s) 11000 0.1828 95
# 412m 37s (- -413m 24s) 12000 0.1948 95
# 0.0000,0.0108
# (0.4559770937723694, 0.09669811320754718)
# 96
# 413m 4s (- -413m 19s) 1000 0.2353 96
# 413m 25s (- -414m 46s) 2000 0.2064 96
# 413m 46s (- -414m 21s) 3000 0.1880 96
# 414m 7s (- -415m 58s) 4000 0.2348 96
# 414m 28s (- -415m 36s) 5000 0.2201 96
# 414m 49s (- -415m 14s) 6000 0.2516 96
# 415m 9s (- -416m 53s) 7000 0.2277 96
# 415m 31s (- -416m 31s) 8000 0.2100 96
# 415m 52s (- -416m 10s) 9000 0.1885 96
# 416m 12s (- -417m 49s) 10000 0.1984 96
# 416m 33s (- -417m 28s) 11000 0.1787 96
# 416m 54s (- -417m 7s) 12000 0.1839 96
# 0.0001,0.0395
# (0.4609878310665712, 0.08726415094339622)
# 97
# 417m 21s (- -417m 3s) 1000 0.2242 97
# 417m 43s (- -418m 29s) 2000 0.1915 97
# 418m 3s (- -418m 4s) 3000 0.1897 97
# 418m 24s (- -419m 41s) 4000 0.2129 97
# 418m 45s (- -419m 19s) 5000 0.2102 97
# 419m 7s (- -420m 57s) 6000 0.2306 97
# 419m 27s (- -420m 35s) 7000 0.2106 97
# 419m 48s (- -420m 14s) 8000 0.1948 97
# 420m 9s (- -421m 52s) 9000 0.1794 97
# 420m 30s (- -421m 31s) 10000 0.1924 97
# 420m 51s (- -421m 10s) 11000 0.1716 97
# 421m 12s (- -422m 49s) 12000 0.1818 97
# 0.0000,0.0207
# (0.4652827487473157, 0.10613207547169812)
# 98
# 421m 39s (- -422m 45s) 1000 0.2132 98
# 422m 0s (- -422m 11s) 2000 0.1788 98
# 422m 21s (- -423m 46s) 3000 0.1721 98
# 422m 42s (- -423m 23s) 4000 0.2052 98
# 423m 3s (- -423m 1s) 5000 0.2025 98
# 423m 25s (- -424m 38s) 6000 0.2213 98
# 423m 45s (- -424m 17s) 7000 0.2007 98
# 424m 7s (- -425m 55s) 8000 0.1792 98
# 424m 28s (- -425m 33s) 9000 0.1641 98
# 424m 49s (- -425m 13s) 10000 0.1816 98
# 425m 10s (- -426m 51s) 11000 0.1580 98
# 425m 31s (- -426m 30s) 12000 0.1733 98
# 0.0000,0.0127
# (0.4767358625626342, 0.10141509433962265)
018867924528301), (0.4022906227630637, 0.049528301886792456), (0.23979957050823192, 0.007075471698113208), (0.21832498210450965, 0.0047169811320754715), (0.23335719398711524, 0.009433962264150943), (0.26628489620615603, 0.018867924528301886), (0.25841088045812455, 0.0047169811320754715), (0.2934860415175376, 0.018867924528301886), (0.30708661417322836, 0.025943396226415096), (0.33070866141732286, 0.02830188679245283), (0.3278453829634932, 0.02358490566037736), (0.3457408732999284, 0.03537735849056604), (0.3536148890479599, 0.03537735849056604), (0.3586256263421618, 0.04245283018867924), (0.380100214745884, 0.04716981132075472), (0.3829634931997137, 0.0660377358490566), (0.4030064423765211, 0.05660377358490566), (0.41589119541875447, 0.06132075471698113), (0.4180386542591267, 0.06132075 ...

# %%
evaluateRandomly(encoder1, decoder1)
# Out:
# incorrect:  ['الخطابي', 'أَن', 'حَبَّةَ', 'العُرَنيَّ'] ['الخطابي', 'أَن', 'حَبّةَ', 'العُرَنيّ']
# incorrect:  ['أَرض', 'في', 'أَنه', 'مؤَنث'] ['أَرض', 'في', 'أَنه', 'مُؤَنّثٌ']
# incorrect:  ['على', 'أَحَرَّ', 'كأَنه', 'أَراد'] ['على', 'أَحَرّ', 'كأَنه', 'أَراد']
# incorrect:  ['حَرَّ', 'العبدُ', 'يَحَرُّ', 'حَرارَةً'] ['حَرّ', 'العبدُ', 'يَحِرّ', 'حَرارةً']
# incorrect:  ['إِلى', 'أَهله', 'أَي', 'صاحبه'] ['إِلى', 'أَهلُه', 'أَي', 'صاحبَه']
# incorrect:  ['عليها', 'كُلُّ', 'بِكْرٍ', 'حُرَّةٍ'] ['عليها', 'كلّ', 'بِكْرٌ', 'حَرّةٌ']
# incorrect:  ['من', 'الحُسن', 'إِلا', 'أَن'] ['من', 'الحسْنِ', 'إِلا', 'أَن']
# incorrect:  ['ويقال', 'ساقُ', 'حُرٍّ', 'صَوْتُ'] ['ويقال', 'ساق', 'حَرّ', 'صَوْتِ']
# incorrect:  ['سَاقَ', 'حُرٍّ', 'إِن', 'كان'] ['ساق', 'حَرّ', 'إِنّ', 'كان']
# incorrect:  ['عَرَفْتُ', 'من', 'ضَرْب', 'الحَرِيرِ'] ['عَرفْت', 'من', 'ضرْب', 'الحَريرِ']
# incorrect:  ['للضأْن', 'وفي', 'المحكَم', 'وحَرِّ'] ['للضأْن', 'وفي', 'المحكم', 'وحَرّ']
# incorrect:  ['فقال', 'القَبِيلة', 'إِلا', 'أَنهم'] ['فقال', 'القَبَيلَةِ', 'إِلا', 'أَنهم']
# incorrect:  ['إِبلاً', 'لأَنها', 'كانت', 'أَموالَهم'] ['إِبلاً', 'لأَنها', 'كانَت', 'أَموالهم']
# correct:  ['أَن', 'رجلاً', 'أَتاه', 'فقال'] ['أَن', 'رجلاً', 'أَتاه', 'فقال']
# incorrect:  ['مَعْقُلة', 'أَي', 'بَقِيَّةٌ', 'من'] ['مَعْقُلَة', 'أَي', 'بقيةٌ', 'من']
# incorrect:  ['الخطابي', 'إِنما', 'يُضْرَب', 'المثَل'] ['الخطابي', 'إِنما', 'يضرِب', 'المثلِ']
# incorrect:  ['الأَول', 'حديثُ', 'عمر', 'أَنه'] ['الأَوّل', 'حديث', 'عمر', 'أَنه']
# incorrect:  ['لَقَدْ', 'عَلِمَ', 'القومُ', 'أَنَّا'] ['لقد', 'عِلم', 'القوم', 'أَنا']
# incorrect:  ['وإِنما', 'سُمِّيت', 'مَعْقُلة', 'لأَنها'] ['وإِنما', 'سمّيت', 'مَعْقُلَة', 'لأَنها']
# incorrect:  ['أَنه', 'أُمسِك', 'على', 'المَوْت'] ['أَنه', 'أَمْسك', 'على', 'المَوتَ']
# incorrect:  ['نفسَه', 'وكلُّ', 'من', 'قُتِل'] ['نَفْسُه', 'وكلّ', 'من', 'قتل']
# incorrect:  ['أَرَى', 'أُمَّ', 'زَيْدٍ', 'كُلَّمَا'] ['أَرى', 'أُمّ', 'زيد', 'كلما']
# incorrect:  ['عزَّ', 'وجلَّ', 'أَي', 'أَشدّ'] ['عَزّ', 'وجل', 'أَي', 'أَشد']
# incorrect:  ['لأَنه', 'قُتِل', 'وحُمِل', 'رأْسهُ'] ['لأَنه', 'قتل', 'وحَمْلٌ', 'رأْسَه']
# incorrect:  ['إِنما', 'هو', 'مِثْلُ', 'جَبَلِ'] ['إِنما', 'هو', 'مثل', 'جبَلٌ']
# incorrect:  ['وقد', 'نصَب', 'قولَ', 'قومٌ'] ['وقد', 'نصَبَ', 'قول', 'قوم']
# incorrect:  ['بلغت', 'أمُّه', 'أوَانَ', 'الحَمْل'] ['بَلَغْت', 'أُمّه', 'أَوانَ', 'الحِمْل']
# incorrect:  ['لها', 'دُون', 'حِقِّها', 'إِذا'] ['لها', 'دون', 'حقّها', 'إِذا']
# incorrect:  ['لَقاحها', 'أَيضاً', 'بالكسر', 'أَي'] ['لَقاحُها', 'أَيضاً', 'بالكسر', 'أَي']
# incorrect:  ['أَبو', 'عمرو', 'أَبا', 'خَيْرَةَ'] ['أَبو', 'عمْرٌو', 'أَبا', 'خيرة']
# incorrect:  ['عُمَارة', 'أَنه', 'كان', 'يقرأُ'] ['عِمارةً', 'أَنه', 'كان', 'يقرأْ']
# incorrect:  ['أَي', 'أَجْرِهِ', 'حتى', 'يَعْرَقَ'] ['أَي', 'أَجره', 'حتى', 'يَعْرَقُ']
# incorrect:  ['العظمَ', 'تَعْرُقِ', 'وقوله', 'أَنشده'] ['العِظْمِ', 'تُعَرّق', 'وقوله', 'أَنشده']
# incorrect:  ['الأُسُود', 'ويروى', 'باحَة', 'العِراقِ'] ['الأَسود', 'ويُرْوى', 'باحَةُ', 'العِراق']
# incorrect:  ['القومُ', 'أَتوا', 'العِراقَ', 'قال'] ['القوم', 'أَتَوا', 'العِراق', 'قال']
# correct:  ['أَنشده', 'ابن', 'الأَعرابي', 'إِذا'] ['أَنشده', 'ابن', 'الأَعرابي', 'إِذا']
# incorrect:  ['وجه', 'الأَرض', 'وأَما', 'الأَكمة'] ['وَجْهٍ', 'الأَرض', 'وأَما', 'الأُككة']
# incorrect:  ['غليظ', 'جداًّ', 'يُنْبِت', 'فأَما'] ['غليظ', 'جدّاً', 'يَنْبُتُ', 'فأَمّا']
# incorrect:  ['الليث', 'كأنَّ', 'صَوْتَ', 'خِلْفِها'] ['الليث', 'كأَنّ', 'صَوْتِ', 'خَلْفِها']
# correct:  ['عَمْراً', 'تفاؤلاً', 'أَن', 'يبقىوالعرب'] ['عَمْراً', 'تفاؤلاً', 'أَن', 'يبقىوالعرب']
# correct:  ['قَسَمِي', 'أَو', 'يميني', 'أَو'] ['قَسَمِي', 'أَو', 'يميني', 'أَو']
# incorrect:  ['الدِّينُ', 'وأَيّاً', 'كان', 'فإِنه'] ['الدّينُ', 'وأَيّاً', 'كان', 'فإِنه']
# incorrect:  ['لَعَمْرُك', 'إِنّهم', 'لفي', 'سَكْرتِهم'] ['لَعَمْرُك', 'إِنهم', 'لفي', 'سَكْرتِهم']
# correct:  ['يَعْمَهُون', 'لم', 'يقرأْ', 'إِلا'] ['يَعْمَهُون', 'لم', 'يقرأْ', 'إِلا']
# incorrect:  ['أَبي', 'الطَّيْرِ', 'المُرِنّة', 'عُذْرةً'] ['أَبي', 'الطّيْر', 'المُرِنّة', 'عِذْرةٌ']
# incorrect:  ['لعَمْرُك', 'لَدِينُك', 'الذي', 'تَعْمُر'] ['لَعَمْرُك', 'لَدِينُك', 'الذي', 'تَعْمُر']
# incorrect:  ['أَيُّها', 'المُنْكِحُ', 'الثُّرَيّا', 'سُهَيْلاً'] ['أَيّها', 'المنْكِحُ', 'الثُرَيّا', 'سُهَيْلاً']
# incorrect:  ['عَمْرَكَ', 'اللهَ', 'كيف', 'يَجْتَمِعان'] ['عمْرك', 'اللهُ', 'كيفٍ', 'يَجْتَمِعان']
# incorrect:  ['اللهَ', 'فنصب', 'وأَنشد', 'عَمْرَكِ'] ['اللهُ', 'فنصب', 'وأَنشد', 'عمْرك']
# incorrect:  ['اللهَ', 'ساعةً', 'حَدِّثِينا', 'وذَرِينا'] ['اللهُ', 'ساعةَ', 'حَدّثِينا', 'وذَرِينا']
# incorrect:  ['مِن', 'قَوْلِ', 'مَن', 'يُؤْذِينا'] ['من', 'قول', 'من', 'يُؤْذِينا']
# correct:  ['قوله', 'لَعَمْرُك', 'إِنهم', 'وعَيْشِك'] ['قوله', 'لَعَمْرُك', 'إِنهم', 'وعَيْشِك']
# incorrect:  ['وإِنما', 'يريد', 'العُمْرَوقال', 'أَهل'] ['وإِنما', 'يرِيد', 'العُمْرَوقال', 'أَهلُ']
# incorrect:  ['رَفَعَه', 'لَعَمْرُك', 'المحلوفُ', 'به'] ['رفعه', 'لَعَمْرُك', 'المحلوفُ', 'به']
# incorrect:  ['عَمْرَك', 'اللهَ', 'فكأَنك', 'قلت'] ['عمْرك', 'اللهُ', 'فكأَنك', 'قلّت']
# incorrect:  ['بِتَعْمِيرِك', 'الله', 'أَي', 'بإِقرارك'] ['بِتَعْمِيرِك', 'اللهُ', 'أَي', 'بإِقرارك']
# incorrect:  ['سأَلتُ', 'الله', 'أَن', 'يُطيل'] ['سأَلت', 'اللهُ', 'أَن', 'يُطيل']
# incorrect:  ['عُمْرَك', 'لأَنه', 'لم', 'يُرِد'] ['عمْرك', 'لأَنه', 'لم', 'يُرِد']
# incorrect:  ['فإِذا', 'أَدخلتها', 'رَفَعْت', 'بها'] ['فإِذا', 'أَدخلتها', 'رَفَعْتُ', 'بها']
# incorrect:  ['أَبيك', 'فإِذا', 'قلت', 'لَعَمْرُ'] ['أَبيك', 'فإِذا', 'قلّت', 'لَعَمْرُ']
# incorrect:  ['أَبيك', 'الخَيْرَ', 'نَصَبْتَ', 'الخير'] ['أَبيك', 'الخير', 'نَصَبْتَ', 'الخير']
# incorrect:  ['أَن', 'أَباك', 'عَمَرَ', 'الخيرَ'] ['أَن', 'أَباكِ', 'عمر', 'الخير']
# incorrect:  ['يَعْمُرُه', 'عَمْراً', 'وعِمارةً', 'فنصب'] ['يَعْمُرُه', 'عَمْراً', 'وعُمارَةَ', 'فنصب']
# incorrect:  ['نعتاً', 'لأَبيك', 'وعَمْرَك', 'اللهَ'] ['نعْتاً', 'لأَبيك', 'وعُمْرَكَ', 'اللهُ']
# incorrect:  ['كأَنه', 'قال', 'وعَمْرِك', 'فلَعَمْرُك'] ['كأَنه', 'قال', 'وعُمْرَكَ', 'فلَعَمْرُك']
# correct:  ['لَيَجْمَعَنّكم', 'كأَنه', 'أَراد', 'والله'] ['لَيَجْمَعَنّكم', 'كأَنه', 'أَراد', 'والله']
# correct:  ['بفعلٍ', 'أَضمرتَه', 'وإِن', 'شئت'] ['بفعلٍ', 'أَضمرتَه', 'وإِن', 'شئت']
# incorrect:  ['تَعْمِيراً', 'ونَشَدْتُك', 'الله', 'نَشِيداً'] ['تَعْميراً', 'ونَشَدْتُك', 'اللهُ', 'نَشِيداً']
# incorrect:  ['عَمَّرْتُكِ', 'اللهَ', 'أَلا', 'ما'] ['عَمّرْتُكَ', 'اللهُ', 'أَلا', 'ما']
# correct:  ['جارتَنا', 'أَيام', 'ذِي', 'سَلَمِ'] ['جارتَنا', 'أَيام', 'ذِي', 'سَلَمِ']
# incorrect:  ['إِنّك', 'عَمْرِي', 'لَظَرِيفٌ', 'ابن'] ['إِنك', 'عُمْرِي', 'لَظَرِيفٌ', 'ابن']
# incorrect:  ['أَعرابي', 'حِمْلَ', 'خَبَطٍ', 'فلما'] ['أَعرابي', 'حَمْلُ', 'خَبَطٍ', 'فلمّا']
# incorrect:  ['عَمْرَكَ', 'اللهَ', 'بَيْعاً', 'أَي'] ['عمْرك', 'اللهُ', 'بَيْعاً', 'أَي']
# incorrect:  ['أَسأَلُ', 'الله', 'تَعْمِيرَك', 'وأَن'] ['أَسأَلُ', 'اللهُ', 'تَعْمِيرَك', 'وأَن']
# incorrect:  ['يُطيل', 'عُمْرك', 'وبَيِّعاً', 'منصوب'] ['يُطيل', 'عمْرك', 'وبَيّعاً', 'منصوب']
# incorrect:  ['اللهُ', 'مِن', 'بَيِّعٍوفي', 'حديث'] ['اللهُ', 'من', 'بَيّعٍوفي', 'حديث']
# correct:  ['لَقِيط', 'لَعَمْرُ', 'إِلَهِك', 'هو'] ['لَقِيط', 'لَعَمْرُ', 'إِلَهِك', 'هو']
# incorrect:  ['عَمْرَك', 'اللهَ', 'افْعَلْ', 'كذا'] ['عمْرك', 'اللهُ', 'افْعَلْ', 'كذا']
# incorrect:  ['إِظهارُه', 'وأَصله', 'مِنْ', 'عَمَّرْتُك'] ['إِظهارُه', 'وأَصله', 'من', 'عَمّرْتُكَ']
# incorrect:  ['كأَنك', 'تُحَلِّفه', 'بالله', 'وتسأَله'] ['كأَنك', 'تحلّته', 'بالله', 'وتَسأَله']
# incorrect:  ['اللهَ', 'الجَلِيلَ', 'فإِنّني', 'أَلْوِي'] ['اللهُ', 'الجَلِيلَ', 'فإِنّني', 'أَلْوِي']
# incorrect:  ['عليك', 'لَوَانّ', 'لُبَّكَ', 'يَهْتَدِي'] ['عليك', 'لَوَانّ', 'لُبّك', 'يَهْتَدِي']
# incorrect:  ['معنى', 'عَمَرْتُك', 'اللهَ', 'أَي'] ['معنى', 'عَمّرْتُكَ', 'اللهُ', 'أَي']
# incorrect:  ['سأَلت', 'الله', 'أَن', 'يُعَمِّرَك'] ['سأَلت', 'اللهُ', 'أَن', 'يُعمّرَك']
# incorrect:  ['قبيح', 'وعَمِرَ', 'الرجلُ', 'يَعْمَرُ'] ['قبيح', 'وعُمْرٌ', 'الرجلُ', 'يَعمرُ']
# incorrect:  ['عَمَراً', 'وعَمارةً', 'وعَمْراً', 'وعَمَر'] ['عَمْراً', 'وعُمارَةَ', 'وعَمْراً', 'وعُمْرٌ']
# incorrect:  ['يَعْمُرُ', 'ويَعْمِر', 'الأَخيرة', 'عن'] ['يَعمرُ', 'ويَعْمَرُ', 'الأَخيرة', 'عن']
# incorrect:  ['زماناً', 'طويلاً', 'قال', 'لبيدوعَمَرْتُ'] ['زَماناً', 'طويلاً', 'قال', 'لبيدوعَمَرْتُ']
# incorrect:  ['حَرْساً', 'قبل', 'مَجْرَى', 'داحِسٍ'] ['حَرْساً', 'قبل', 'مُجْرَى', 'داحِسٍ']
# correct:  ['عَمِرَتْ', 'تَيْمٌ', 'زَماناً', 'بِغِرّةٍ'] ['عَمِرَتْ', 'تَيْمٌ', 'زَماناً', 'بِغِرّةٍ']
# correct:  ['لقد', 'حُدِيَتْ', 'تَيْمٌ', 'حُداءً'] ['لقد', 'حُدِيَتْ', 'تَيْمٌ', 'حُداءً']
# incorrect:  ['الله', 'عَمْرَك', 'وعُمْرَك', 'وإِن'] ['اللهُ', 'عمْرك', 'وعُمْرَكَ', 'وإِن']
# incorrect:  ['اللهُ', 'وعَمَرَه', 'أَبقاه', 'وعَمَّرَ'] ['اللهُ', 'وعُمّرُهُ', 'أَبْقاه', 'وعُمْرٌ']
# incorrect:  ['نَفْسَه', 'قدَّر', 'لها', 'قدْراً'] ['نَفْسُه', 'قدّرَ', 'لها', 'قِدَراً']
# incorrect:  ['يُعَمَّرُ', 'مِن', 'مُعَمَّرٍ', 'ولا'] ['يَعمرُ', 'من', 'مَعْمَرٍ', 'ولا']
# incorrect:  ['يُنْقَص', 'من', 'عُمُرِه', 'إِلا'] ['يُنْقَص', 'من', 'عُمْرِه', 'إِلا']
# incorrect:  ['يُطَوَّلُ', 'مِن', 'عُمُرِ', 'مُعَمَّر'] ['يُطَوّلُ', 'من', 'عمر', 'مَعْمَرٍ']
# incorrect:  ['مُعَمَّرٍ', 'ولا', 'يُنْقَص', 'مِن'] ['مَعْمَرٍ', 'ولا', 'يُنْقَص', 'من']
# incorrect:  ['عُمُرِه', 'يقول', 'إِذا', 'أَتى'] ['عُمْرِه', 'يقول', 'إِذا', 'أَتى']
# incorrect:  ['وكأَن', 'الأَول', 'أَشبه', 'بالصواب'] ['وكأَنّ', 'الأَوّل', 'أَشبه', 'بالصواب']
# incorrect:  ['للرجل', 'طولَ', 'عُمُرِك', 'أَو'] ['للرجل', 'طولَ', 'عمْرك', 'أَو']
# correct:  ['عُمُرِهوقال', 'ثعلب', 'العُمْرَى', 'أَن'] ['عُمُرِهوقال', 'ثعلب', 'العُمْرَى', 'أَن']
# incorrect:  ['عُمُرَك', 'أَو', 'عُمُرِي', 'أَيُّنا'] ['عمْرك', 'أَو', 'عُمْرِي', 'أَيّنا']
# incorrect:  ['وأَعْمَرْته', 'جعلتُه', 'له', 'عُمُرَه'] ['وأعْمَرْته', 'جعَلْته', 'له', 'عُمْرِه']
# incorrect:  ['أَو', 'عُمُرِي', 'والعُمْرَى', 'المصدرُ'] ['أَو', 'عُمْرِي', 'والعُمْرَى', 'المصدر']
# incorrect:  ['تُرْقِبُوا', 'فمن', 'أُعْمِرَ', 'داراً'] ['تُرْقِبُوا', 'فمن', 'أُعْمَر', 'داراً']
# incorrect:  ['العُمْرَى', 'والرُّقْبَى', 'يقال', 'أَعْمَرْتُه'] ['العُمْرَى', 'والرّقْبى', 'يقال', 'أَعْمَرْتُه']
# incorrect:  ['أَن', 'من', 'أُعْمِرَ', 'شيئاً'] ['أَن', 'من', 'أُعْمَر', 'شيئاً']
# incorrect:  ['قال', 'الأَزهري', 'والرُّقْبى', 'أَن'] ['قال', 'الأَزهري', 'والرّقْبى', 'أَن']
# incorrect:  ['مُتَّ', 'قبلي', 'رجعَتْ', 'إِليَّ'] ['متّ', 'قبلي', 'رجعتْ', 'إِليّ']
# incorrect:  ['لكوأَصل', 'العُمْرَى', 'مأَخوذ', 'من'] ['لكوأَصل', 'العُمْرَى', 'مأْخوذ', 'من']
# incorrect:  ['العُمْر', 'وأَصل', 'الرُّقْبَى', 'من'] ['العمْرِ', 'وأَصل', 'الرّقْبَى', 'من']
# incorrect:  ['الصحاح', 'أَعْمَرْتُه', 'داراً', 'أَو'] ['الصحاحُ', 'أَعْمَرْتُه', 'داراً', 'أَو']
# incorrect:  ['أَرضاً', 'أَو', 'إِبِلاً', 'قال'] ['أَرضاً', 'أَو', 'إِبلاً', 'قال']
# incorrect:  ['المالُ', 'إِلا', 'مُعْمَراتٌ', 'وَدائِعُ'] ['المال', 'إِلا', 'مَعْمَراتٌ', 'وَدائِعُ']
# incorrect:  ['وما', 'المالُ', 'والأَهْلُون', 'إِلا'] ['وما', 'المال', 'والأَهْلُون', 'إِلا']
# incorrect:  ['أَن', 'تُرَدَّ', 'الوَدائِعُ', 'أَي'] ['أَن', 'تُرَدّ', 'الوَدائِعُ', 'أَي']
# incorrect:  ['الشجرِ', 'قديمُه', 'نسب', 'إِلى'] ['الشّجرِ', 'قدِيمُه', 'نسب', 'إِلى']
# incorrect:  ['الأَصمعي', 'العُمْرِيّ', 'والعُبْرِيّ', 'من'] ['الأَصمعي', 'العَمْرِيّ', 'والعُبْرِيّ', 'من']
# incorrect:  ['والضّالُ', 'الحديثُ', 'منه', 'وأَنشد'] ['والضّالُ', 'الحديث', 'منه', 'وأَنشد']
# incorrect:  ['إِذا', 'تَجَوَّفت', 'العَواطِي', 'ضُروبَ'] ['إِذا', 'تَجَوّفت', 'العَواطِي', 'ضُروبَ']
# correct:  ['بن', 'مَسْلمة', 'ومُحارَبتِه', 'مَرْحَباً'] ['بن', 'مَسْلمة', 'ومُحارَبتِه', 'مَرْحَباً']
# correct:  ['يَلِيه', 'حتى', 'يَخْلَصَ', 'إِليه'] ['يَلِيه', 'حتى', 'يَخْلَصَ', 'إِليه']
# incorrect:  ['على', 'الأَنهار', 'عُمْرِيّ', 'وعُبْرِيّ'] ['على', 'الأَنْهار', 'عُمْرِي', 'وعُبْرِيّ']
# incorrect:  ['بك', 'منزِلَك', 'يَعْمُره', 'عِمارة'] ['بك', 'منزِلَكَ', 'يَعْمُرُه', 'عِمارةً']
# incorrect:  ['وأَعْمَره', 'جعلَه', 'آهِلاًومكان', 'عامِرٌ'] ['وأعْمَره', 'جعلَه', 'آهِلاًومكا', 'عامرٌ']
# incorrect:  ['ذو', 'عِمَارةٍومكان', 'عَمِيرٌ', 'عامِرٌ'] ['ذو', 'عِمَارةٍومكان', 'عَمِيْر', 'عامرٌ']
# incorrect:  ['أَعْمَر', 'الرجلُ', 'منزلَه', 'بالأَلف'] ['أُعْمَر', 'الرجلُ', 'منزلَه', 'بالأَلف']
# incorrect:  ['وأَعْمَرْتُ', 'الأَرضَ', 'وجدتها', 'عامرةًوثوبٌ'] ['وأعْمَرْتُ', 'الأَرض', 'وجدتها', 'عامرةًوثوبٌ']
# incorrect:  ['عَمِيرٌ', 'أَي', 'صَفِيق', 'وعَمَرْت'] ['عَمِيْر', 'أَي', 'صَفِيق', 'وعَمَرْت']
# incorrect:  ['الخَرابَ', 'أَعْمُره', 'عِمارةً', 'فهو'] ['الخرابَ', 'أَعْمُره', 'عِمارةً', 'فهو']
# incorrect:  ['عامِرٌ', 'أَي', 'مَعْمورٌ', 'مثل'] ['عامرٌ', 'أَي', 'مَعْمورٌ', 'مثل']
# incorrect:  ['راضية', 'أَي', 'مَرْضِيّة', 'وعَمَر'] ['راضيةٍ', 'أَي', 'مَرْضِيّة', 'وعُمْرٌ']
# incorrect:  ['الرجلُ', 'مالَه', 'وبيتَه', 'يَعْمُره'] ['الرجلُ', 'مالَه', 'وبَيتَه', 'يَعْمُرُه']
# incorrect:  ['عِمارةً', 'وعُموراً', 'وعُمْراناً', 'لَزِمَه'] ['عِمارةً', 'وعُمُوراً', 'وعُمْراناً', 'لَزِمَه']
# correct:  ['وأَنشد', 'أَبو', 'حنيفة', 'لأَبي'] ['وأَنشد', 'أَبو', 'حنيفة', 'لأَبي']
# correct:  ['أَدامَ', 'لها', 'العَصْرَيْنِ', 'رَيّاً'] ['أَدامَ', 'لها', 'العَصْرَيْنِ', 'رَيّاً']
# incorrect:  ['عَمِرَ', 'فلان', 'يَعْمَر', 'إِذا'] ['عمر', 'فلان', 'يَعمرُ', 'إِذا']
# incorrect:  ['المخدومُ', 'وعَمَرْت', 'رَبِّي', 'وحَجَجْته'] ['المخدومُ', 'وعَمَرْت', 'رَبّي', 'وحَجَجْته']
# incorrect:  ['أَي', 'خدمته', 'وعَمَر', 'المالُ'] ['أَي', 'خدمته', 'وعُمْرٌ', 'المال']
# incorrect:  ['نَفْسُه', 'يَعْمُرُ', 'وعَمُر', 'عَمارةً'] ['نَفْسُه', 'يَعمرُ', 'وعُمْرٌ', 'عِمارةً']
# correct:  ['أَنشأَكم', 'من', 'الأَرض', 'واسْتَعْمَرَكم'] ['أَنشأَكم', 'من', 'الأَرض', 'واسْتَعْمَرَكم']
# correct:  ['في', 'عِمارتها', 'واستخراجِ', 'قومِكم'] ['في', 'عِمارتها', 'واستخراجِ', 'قومِكم']
# incorrect:  ['منها', 'وجعَلَكم', 'عُمَّارَها', 'والمَعْمَرُ'] ['منها', 'وجعَلَكم', 'عُمّارُها', 'والمَعْمَرُ']
# incorrect:  ['الساجع', 'أَرْسِل', 'العُراضاتِ', 'أَثَرا'] ['الساجع', 'أَرْسِل', 'العراضاتِ', 'أَثَرا']
# correct:  ['يَبْغِينَك', 'في', 'الأَرض', 'مَعْمَرا'] ['يَبْغِينَك', 'في', 'الأَرض', 'مَعْمَرا']
# incorrect:  ['فبَقِيت', 'بَعْدَك', 'غيرَ', 'راضي'] ['فبَقِيت', 'بَعدَكَ', 'غيْرُ', 'راضي']
# incorrect:  ['لا', 'تَجْزَعِي', 'إِن', 'مُنْفِساً'] ['لا', 'تَجْزَعِي', 'إِنّ', 'مُنْفِساً']
# correct:  ['أَهْلَكْتُه', 'فإِذا', 'هَلكتُ', 'فعِنْدَ'] ['أَهْلَكْتُه', 'فإِذا', 'هَلكتُ', 'فعِنْدَ']
# incorrect:  ['أَجْرُ', 'العِمَارة', 'وأَعْمَرَ', 'عليه'] ['أَجْرٌ', 'العِمارة', 'وأعْمَرٌ', 'عليه']
# incorrect:  ['العُمَروقوله', 'تعالى', 'وأَتِمُّوا', 'الحجَّ'] ['العُمَروقوله', 'تعالى', 'وأَتِمّوا', 'الحجّ']
# incorrect:  ['والعُمْرة', 'مأَخوذة', 'من', 'الاعْتِمار'] ['والعُمْرةُ', 'مأْخوذة', 'من', 'الاعْتِمار']
# incorrect:  ['إِنما', 'خُصَّ', 'بهذا', 'لأَنه'] ['إِنما', 'خُصّ', 'بهذا', 'لأَنه']
# incorrect:  ['الاعْتِمار', 'العُمْرة', 'سَماها', 'بالمصدروفي'] ['الاعْتِمار', 'العمْرة', 'سَماها', 'بالمصدروفي']
# incorrect:  ['الحديث', 'ذكرُ', 'العُمْرة', 'والاعْتِمار'] ['الحديث', 'ذُكرُ', 'العمْرة', 'والاعْتِمار']
# incorrect:  ['ذَرٍّ', 'فقال', 'أَحَلَقْتم', 'الشَّعَث'] ['ذَرّ', 'فقال', 'أَحَلَقْتم', 'الشّعْثِ']
# incorrect:  ['وقضيتم', 'التَّفَثَ', 'عُمّاراً', 'أَي'] ['وقضيتم', 'التّفَثَ', 'عِمّاراً', 'أَي']
# incorrect:  ['اللهَ', 'إِذا', 'عبده', 'وعَمَر'] ['اللهُ', 'إِذا', 'عبَدَه', 'وعُمْرٌ']
# incorrect:  ['وهو', 'يَعْمُر', 'ربَّه', 'أَي'] ['وهو', 'يَعمرُ', 'ربّه', 'أَي']
# incorrect:  ['عمامة', 'أَو', 'قَلَنْسُوَةٍ', 'أَو'] ['عمامَة', 'أَو', 'قَلَنْسُوَةٍ', 'أَو']
# incorrect:  ['اعْتَمَر', 'أَي', 'تعمّم', 'بالعمامة'] ['اعتمر', 'أَي', 'تعمّم', 'بالعمامة']
# incorrect:  ['قول', 'الأَعشى', 'فَلَمَّا', 'أَتانا'] ['قول', 'الأَعشى', 'فلمّا', 'أَتانا']
# incorrect:  ['بُعَيْدَ', 'الكَرى', 'سَجَدْنا', 'لَهُ'] ['بُعيد', 'الكَرى', 'سَجَدْنا', 'له']
# incorrect:  ['ورَفَعْنا', 'العَمارا', 'أَي', 'وضعناه'] ['ورَفَعنا', 'العَمارا', 'أَي', 'وضعناه']
# correct:  ['أَي', 'زارَه', 'يقال', 'أَتانا'] ['أَي', 'زارَه', 'يقال', 'أَتانا']
# correct:  ['فلان', 'مُعْتَمِراً', 'أَي', 'زائراً'] ['فلان', 'مُعْتَمِراً', 'أَي', 'زائراً']
# incorrect:  ['وجاشَت', 'النَّفْسُ', 'لَمَّا', 'جاءَ'] ['وجاشَت', 'النفس', 'لمّا', 'جاء']
# incorrect:  ['تَثْلِيثَ', 'مُعْتَمِرُ', 'قال', 'الأَصمعي'] ['تَثْليثَ', 'مُعْتَمِرُ', 'قال', 'الأَصمعي']
# incorrect:  ['بالفَرْقَدِ', 'رُكْبانُها', 'كما', 'يُهِلُّ'] ['بالفَرْقد', 'رُكْبانُها', 'كما', 'يُهلّ']
# correct:  ['قال', 'الأَصمعي', 'إِذا', 'انْجلى'] ['قال', 'الأَصمعي', 'إِذا', 'انْجلى']
# incorrect:  ['أَهَلّوا', 'أَي', 'رفعوا', 'أَصواتهم'] ['أَهلّوا', 'أَي', 'رفعوا', 'أَصواتهم']
# incorrect:  ['المياه', 'فإِذا', 'رأَوْا', 'فرقداً'] ['المياهُ', 'فإِذا', 'رأَوْا', 'فرقداً']
# correct:  ['أَهلّوا', 'أَي', 'كبّروا', 'لأَنهم'] ['أَهلّوا', 'أَي', 'كبّروا', 'لأَنهم']
# incorrect:  ['القصدواعْتَمَر', 'الأَمْرَ', 'أَمَّه', 'وقصد'] ['القصدواعْتَمَر', 'الأَمر', 'أُمّه', 'وقصد']
# incorrect:  ['غَزَا', 'ابنُ', 'مَعْمَرٍ', 'حين'] ['غَزَا', 'ابن', 'مَعْمَرٍ', 'حين']
# incorrect:  ['اعْتَمَرْ', 'مَغْزًى', 'بَعِيداً', 'من'] ['اعتمر', 'مَغْزًى', 'بَعِيداً', 'من']
# incorrect:  ['قصد', 'مَغْزًى', 'بعيداًوضبَرَ', 'جَمعَ'] ['قصد', 'مَغْزًى', 'يعياًوبَبَرَرَ', 'جَمعَ']
# incorrect:  ['قوائمه', 'ليَثِبَ', 'والعُمْرةُ', 'أَن'] ['قوائمه', 'ليثِبَ', 'والعُمْرةُ', 'أَن']
# correct:  ['يَبْنِيَ', 'الرجلُ', 'بامرأَته', 'في'] ['يَبْنِيَ', 'الرجلُ', 'بامرأَته', 'في']
# incorrect:  ['أَهلها', 'فإِن', 'نقلها', 'إِلى'] ['أَهْلها', 'فإِن', 'نقلها', 'إِلى']
# incorrect:  ['رَيْحانٍ', 'الطَّيِّب', 'الثناء', 'الطَّيِّب'] ['رَيْحانٍ', 'الطّيّب', 'الثّناء', 'الطّيّب']
# incorrect:  ['وهو', 'الآسوالعِمَارة', 'والعَمارة', 'التحيّة'] ['وهو', 'الآسوالعِمَارة', 'والعَمارة', 'التّحيّة']
# incorrect:  ['عَمّرَك', 'اللهُ', 'وحيّاك', 'وليس'] ['عمْرك', 'اللهُ', 'وحيّاك', 'وليس']
# incorrect:  ['للحُرّة', 'خِمار', 'ولا', 'صَوْقَعة'] ['للحُرّة', 'خِمار', 'ولا', 'صَوْقَعَة']
# incorrect:  ['قامَتْ', 'تُصَلّي', 'والخِمارُ', 'مِن'] ['قامَتْ', 'تُصَلّي', 'والخِمارُ', 'من']
# incorrect:  ['عَمَر', 'ربَّه', 'عبَدَه', 'وإِنه'] ['عمر', 'ربّه', 'عبَدَه', 'وإِنه']
# incorrect:  ['لعَامِرٌ', 'لربّه', 'أَي', 'عابدٌوحكى'] ['لعامِر', 'لربّه', 'أَي', 'عابدٌوحكى']
# incorrect:  ['يَعمرُ', 'ربَّه', 'أَي', 'يعبده'] ['يَعمرُ', 'ربّه', 'أَي', 'يعبده']
# incorrect:  ['أَمره', 'الثَّخينُ', 'الوَرَعِ', 'مأْخوذ'] ['أَمْره', 'الثّخينُ', 'الوَرَعِ', 'مأْخوذ']
# incorrect:  ['الصفيق', 'النسجِ', 'القويُّ', 'الغزلِ'] ['الصفيق', 'النسْجِ', 'القويّ', 'الغزلِ']
# incorrect:  ['وعَمّارٌ', 'المجتمعُ', 'الأَمر', 'اللازمُ'] ['وعِمّارٌ', 'المجتمعُ', 'الأَمر', 'اللازمُ']
# correct:  ['وقائماً', 'بالأَمر', 'والنهي', 'إِلى'] ['وقائماً', 'بالأَمر', 'والنهي', 'إِلى']
# incorrect:  ['وسلم', 'والقيامِ', 'بسُنّته', 'مأْخوذ'] ['وسلم', 'والقيامِ', 'بَسُنّته', 'مأْخوذ']
# incorrect:  ['يَجُوسُ', 'عِمارة', 'ويَكُفّ', 'أُخرى'] ['يَجُوسُ', 'عِمارةً', 'ويَكُفّ', 'أُخرى']
# incorrect:  ['أُناسٍ', 'من', 'مَعَدٍّ', 'عَمارةٍ'] ['أُناسٌ', 'من', 'مَعَدّ', 'عِمارةً']
# incorrect:  ['عَرُوِّضٌ', 'إِليها', 'يَلْجأُون', 'وجانِبُ'] ['عَروّضٌ', 'إِليها', 'يَلْجأُون', 'وجانِبُ']
# incorrect:  ['أَنه', 'كتب', 'لِعَمَائر', 'كَلْب'] ['أَنه', 'كَتب', 'لِعَمَائر', 'كلْب']
# incorrect:  ['وأَحْلافها', 'كتاباً', 'العَمَائرُ', 'جمع'] ['وأَحْلافها', 'كتاباً', 'العِمَائرُ', 'جَمعَ']
# incorrect:  ['وعَمْرة', 'مِن', 'سَرَوات', 'النسا'] ['وعُمْرة', 'من', 'سَرَوات', 'النسا']
# correct:  ['ءِ', 'يَنْفَحُ', 'بالمِسْك', 'أَرْدانُها'] ['ءِ', 'يَنْفَحُ', 'بالمِسْك', 'أَرْدانُها']
# incorrect:  ['والعَمْر', 'الشَّنْف', 'وقيل', 'العَمْر'] ['والعَمْرُ', 'الشّنْف', 'وقيل', 'العمْرِ']
# incorrect:  ['بانَ', 'الشَّبابُ', 'وأَخْلَفَ', 'العَمْرُ'] ['بانَ', 'الشّبابُ', 'وأَخْلَفَ', 'العمْرِ']
# incorrect:  ['وتَبَدَّلَ', 'الإِخْوانُ', 'والدَّهْرُ', 'والجمع'] ['وتَبْدَلُ', 'الإِخْوانُ', 'والدّهْرُ', 'والجمع']
# correct:  ['إِنه', 'أَراد', 'العُمْروجاء', 'فلان'] ['إِنه', 'أَراد', 'العُمْروجاء', 'فلان']
# correct:  ['عَمْراً', 'أَي', 'بطيئاً', 'كذا'] ['عَمْراً', 'أَي', 'بطيئاً', 'كذا']
# incorrect:  ['عَوامِرَ', 'فإِذا', 'رأَيتم', 'منها'] ['عُوامِرَ', 'فإِذا', 'رأَيتم', 'منها']
# incorrect:  ['شيئاً', 'فحَرِّجُوا', 'عليها', 'ثلاثاً'] ['شيئاً', 'فحَرّجُوا', 'عليها', 'ثلاثاً']
# incorrect:  ['اليَعامِيرُ', 'الجِداءُ', 'وصغارُ', 'الضأْن'] ['اليَعامِير', 'الجِداءُ', 'وصغارُ', 'الضأْن']
# incorrect:  ['مِن', 'خَلْفِها', 'نَسَلاً', 'مثل'] ['من', 'خَلْفِها', 'نَسَلاً', 'مثل']
# incorrect:  ['الذَّمِيم', 'على', 'قَرْم', 'اليَعامِير'] ['الذّمِيم', 'على', 'قَرْم', 'اليَعامِير']
# incorrect:  ['كُوَّارة', 'النَّحْل', 'والعُمْرُ', 'ضربٌ'] ['كُوّارة', 'النّحْلِ', 'والعَمْرُ', 'ضرْب']
# incorrect:  ['التمروالعُمور', 'نخلُ', 'السُّكَّر', 'قوله'] ['التمروالعُمور', 'نخل', 'السّكّرِ', 'قوله']
# incorrect:  ['سُحُقٌوقال', 'أَبو', 'حنيفة', 'العَمْرُ'] ['سُحُقٌوقال', 'أَبو', 'حنيفة', 'العمْرِ']
# incorrect:  ['كالليل', 'تَدَجَّى', 'أَخْضَرُهْ', 'مُخالِط'] ['كالليل', 'تَدَجّى', 'أَخْضَرُهْ', 'مُخالِط']
# incorrect:  ['تَعْضوضُه', 'وعُمُرُه', 'بَرْنيّ', 'عَيْدانٍ'] ['تَعْضوضُه', 'وعُمّرُهُ', 'بَرْنيّ', 'عِيْدانٍ']
# incorrect:  ['قَلِيل', 'قَشَرُهْ', 'والتَّعْضوض', 'ضرب'] ['قَلِيلٌ', 'قَشَرُهْ', 'والتّعْضوض', 'ضرْب']
# incorrect:  ['نخل', 'السُّكّر', 'سحوقاً', 'أَو'] ['نخل', 'السّكّرِ', 'سحوقاً', 'أَو']
# incorrect:  ['أَكلت', 'أَنا', 'رُطَبَ', 'العُمُرِ'] ['أَكلت', 'أَنا', 'رُطَبَ', 'العمْرِ']
# incorrect:  ['ورُطَبَ', 'التَّعْضوضِ', 'وخَرَفْتُهما', 'من'] ['ورُطَبَ', 'التّعْضوضِ', 'وخَرَفْتُهما', 'من']
# incorrect:  ['كَثِير', 'بَثِير', 'بَجِير', 'عَمِير'] ['كَثِير', 'بَثِير', 'بَجِير', 'عَمِيْر']
# incorrect:  ['بأْس', 'أَن', 'يُصَلِّيَ', 'الرجلُ'] ['بأُس', 'أَن', 'يُصَلّي', 'الرجلُ']
# incorrect:  ['إِليه', 'عَمِيرِيّ', 'شاذ', 'وعَمْرو'] ['إِليه', 'عَمِيْرِيّ', 'شاذ', 'وعمْرٌو']
# incorrect:  ['بأَبيه', 'وأَجداده', 'وشَيَّدَ', 'لي'] ['بأَبيه', 'وأَجداده', 'وشَيّدَ', 'لي']
# incorrect:  ['زُرارةُ', 'باذِخاتٍ', 'وعَمرو', 'الخير'] ['زُرارةُ', 'باذِخاتٍ', 'وعمْرٌو', 'الخير']
# incorrect:  ['إِن', 'ذُكِرَ', 'العُمورُ', 'الباذِخاتُ'] ['إِنّ', 'ذُكرُ', 'العُمورُ', 'الباذِخاتُ']
# incorrect:  ['لَكَلْبٍ', 'واعْتَزَيْنا', 'لِعامِر', 'وأَما'] ['لكَلْبٍ', 'واعْتَزَيْنا', 'لعامِر', 'وأَما']
# incorrect:  ['عامِـ', 'ـرُ', 'ذو', 'الطُّول'] ['عامِـ', 'ـرُ', 'ذو', 'الطّول']
# correct:  ['وذو', 'العَرْض', 'فإِن', 'أَبا'] ['وذو', 'العَرْض', 'فإِن', 'أَبا']
# incorrect:  ['قامَتْ', 'تُبَكِّيه', 'على', 'قَبْرِه'] ['قامَتْ', 'تُبَكّيه', 'على', 'قَبْرِه']
# incorrect:  ['مَنْ', 'ليَ', 'مِن', 'بَعدِك'] ['من', 'لي', 'من', 'بَعدَكَ']
# correct:  ['ناصِرُ', 'أَي', 'ذات', 'غُرْبة'] ['ناصِرُ', 'أَي', 'ذات', 'غُرْبة']
# incorrect:  ['وإِنما', 'أَنشدنا', 'البيت', 'الأَول'] ['وإِنما', 'أَنشدنا', 'البيت', 'الأَوّل']
# incorrect:  ['العُمَر', 'يُراد', 'العامِروعامِرٌ', 'أَبو'] ['العمْرِ', 'يُراد', 'العاعروعامِرٌ', 'أَبو']
# incorrect:  ['وعَمَّار', 'ومَعْمَر', 'وعُمارة', 'وعِمْران'] ['وعِمّارٌ', 'ومَعْمَرٌ', 'وعُمارَةَ', 'وعِمْرانُ']
# incorrect:  ['عنترةأَحَوْليَ', 'تَنْفُضُ', 'آسْتُك', 'مِذْرَوَيْها'] ['عنترةةأَحَوْي', 'تَنْفُضُ', 'آسْتُك', 'مِذْرَوَيْها']
# incorrect:  ['جرير', 'أَدِيبٌ', 'جدّاً', 'والعَمْرانِ'] ['جرير', 'أَدِيبٌ', 'جدّاً', 'والعُمْرانِ']
# incorrect:  ['عَمْرو', 'بنُ', 'جابر', 'وبَدْرُ'] ['عمْرٌو', 'بن', 'جابِ', 'وبَدْرُ']
# incorrect:  ['بن', 'عَمْرٍو', 'خِلْتَ', 'ذُبْيانَ'] ['بن', 'عمْرٌو', 'خِلْتَ', 'ذُبْيانَ']
# incorrect:  ['تُبَّعا', 'وأَلْقَوْا', 'مَقاليدَ', 'الأُمورِ'] ['تَعْجُاً', 'وأَلْقَوْا', 'مَقاليدَ', 'الأُمورِ']
# incorrect:  ['إِليهما', 'جَمِيعاً', 'قِماءً', 'كارهين'] ['إِليهما', 'جمِيعاً', 'قِماءً', 'كارهين']
# incorrect:  ['وطُوَّعا', 'والعامِرانِ', 'عامِرُ', 'بن'] ['وطُوّعا', 'والعامِران', 'عامرٌ', 'بن']
# incorrect:  ['أَبو', 'براء', 'مُلاعِب', 'الأَسِنَّة'] ['أَبو', 'براء', 'مُلاعِب', 'الأَسِنّة']
# incorrect:  ['والعُمَران', 'أَبو', 'بكر', 'وعُمَر'] ['والعُمْرانِ', 'أَبو', 'بِكْرٌ', 'وعُمْرٌ']
# incorrect:  ['الدار', 'تَسْلُك', 'سِيرةَ', 'العُمَرَيْن'] ['الدارُ', 'تَسْلُكَ', 'سِيرةَ', 'العُمْرِني']
# incorrect:  ['قال', 'الأَزهري', 'العُمَران', 'أَبو'] ['قال', 'الأَزهري', 'العمْران', 'أَبو']
# incorrect:  ['رَبيعة', 'ومُضَر', 'وسُلَيم', 'وعامر'] ['رَبيعة', 'ومُضَرٌ', 'وسُلَيم', 'وعامرٌ']
# incorrect:  ['في', 'مثالٍ', 'مضروبٍ', 'لعُمَر'] ['في', 'مثالُ', 'مضروبٍ', 'لَعَمْرُ']
# incorrect:  ['قوله', 'غُلِّب', 'عُمر', 'لأَنه'] ['قوله', 'غُلّب', 'عمر', 'لأَنه']
# correct:  ['أَو', 'يؤخرون', 'الأَفضل', 'أَو'] ['أَو', 'يؤخرون', 'الأَفضل', 'أَو']
# correct:  ['الأَشرف', 'أَو', 'يبدأُون', 'بالمشروف'] ['الأَشرف', 'أَو', 'يبدأُون', 'بالمشروف']
# correct:  ['الخُلَفاء', 'بعتق', 'أُمّهات', 'الأَولاد'] ['الخُلَفاء', 'بعتق', 'أُمّهات', 'الأَولاد']
# incorrect:  ['وعُمَر', 'خليفةٌ', 'وعَمْرَوَيْهِ', 'اسم'] ['وعُمْرٌ', 'خليفةٌ', 'وعَمْرَوَيْهِ', 'اسمٌ']
# correct:  ['فإِنه', 'زعم', 'أَنه', 'أَعجمي'] ['فإِنه', 'زعم', 'أَنه', 'أَعجمي']
# incorrect:  ['وأَنه', 'ضَرْبٌ', 'من', 'الأَسماء'] ['وأَنه', 'ضرْب', 'من', 'الأَسماء']
# correct:  ['الأَعجمية', 'وأَلزموا', 'آخره', 'شيئاً'] ['الأَعجمية', 'وأَلزموا', 'آخره', 'شيئاً']
# incorrect:  ['ورأَيت', 'سِيبَوَيْهَ', 'فأَعربه', 'ثناه'] ['ورأَيت', 'سيبوَيْهَ', 'فأَعربه', 'ثناه']
# incorrect:  ['يَذْهَب', 'ويَعْمَر', 'الشُِّدّاخ', 'أَحد'] ['يَذهب', 'ويَعْمَرُ', 'الشّدّاخ', 'أَحدٌ']
# correct:  ['حُكّام', 'العربوأَبو', 'عَمْرة', 'رسولُ'] ['حُكّام', 'العربوأَبو', 'عَمْرة', 'رسولُ']
# incorrect:  ['وكان', 'يُتَشاءم', 'بهوأَبو', 'عَمْرة'] ['وكانَ', 'يُتَشاءم', 'بهوأَبو', 'عَمْرة']
# incorrect:  ['الإِقْلالُ', 'قال', 'إِن', 'أَبا'] ['الإِقْلالُ', 'قال', 'إِنّ', 'أَبا']
# incorrect:  ['حلّ', 'أَبو', 'عَمْرة', 'وَسْطَ'] ['حَلّ', 'أَبو', 'عَمْرة', 'وَسَطَ']
# incorrect:  ['حُجْرَتي', 'وأَبو', 'عَمْرة', 'كنية'] ['حُجْرَتي', 'وأَبو', 'عَمْرة', 'كُنْية']
# incorrect:  ['جعلنا', 'النِّساءَ', 'المُرْضِعاتِكَ', 'حَبْوةً'] ['جعلنا', 'النّساءَ', 'المُرْضِعاتِكَ', 'حَبْوةً']
# incorrect:  ['لِرُكْبانِ', 'شَنٍّ', 'والعُمُورِ', 'وأَضْجَما'] ['لِرُكْبانِ', 'شَنّ', 'والعُمُورِ', 'وأَضْجَما']
# incorrect:  ['الهذلي', 'لعلكمُ', 'لَمَّا', 'قُتِلْتُم'] ['الهذلي', 'لعلكم', 'لمّا', 'قُتِلْتُم']
# correct:  ['ذَكَرْتم', 'ولن', 'تَتْركُوا', 'أَن'] ['ذَكَرْتم', 'ولن', 'تَتْركُوا', 'أَن']
# incorrect:  ['تَقْتُلوا', 'مَن', 'تَعَمَّرا', 'قيل'] ['تَقْتُلوا', 'من', 'تَعَمّرا', 'قيل']
# incorrect:  ['جَمّعوا', 'لغدٍ', 'شَمْلَكم', 'لك'] ['جَمّعوا', 'لغدٍ', 'شَمْلَكم', 'لَكَ']
# incorrect:  ['الأُمُّ', 'مما', 'باليَعامِير', 'والأَبُ'] ['الأُمّ', 'ممّا', 'باليَعامِيرُ', 'والأَبُ']
# incorrect:  ['عُمَيْر', 'كنية', 'الفَرْجوأُمُّ', 'عَمْرو'] ['عَمِيْر', 'كُنْية', 'الفَرْجوأُمّ', 'عمْرٌو']
# correct:  ['أَبْشِري', 'بالبُشْرَى', 'مَوْتٌ', 'ذَرِيعٌ'] ['أَبْشِري', 'بالبُشْرَى', 'مَوْتٌ', 'ذَرِيعٌ']
# incorrect:  ['لا', 'تَقْبِرُوني', 'إِنّ', 'قَبْرِي'] ['لا', 'تَقْبِرُوني', 'إِنّ', 'قَبْرِيّ']
# incorrect:  ['وكَمْ', 'مِن', 'وِجارٍ', 'كجَيْبِ'] ['وكَمْ', 'من', 'وِجارٍ', 'كجَيْبِ']
# incorrect:  ['فُرْعُلُ', 'ومن', 'أَمثالهم', 'خامِرِي'] ['فُرْعُلُ', 'ومِنْ', 'أَمثالهم', 'خامِرِي']
# incorrect:  ['أُمَّ', 'عامر', 'أَبْشِري', 'بجرادٍ'] ['أُمّ', 'عامرٌ', 'أَبْشِري', 'بجرادٍ']
# incorrect:  ['عَظْلى', 'وكَمَرِ', 'رجالٍ', 'قَتْلى'] ['عَظْلى', 'وكَمْرِ', 'رجالٍ', 'قَتْلى']
# incorrect:  ['إِلى', 'وجارِها', 'فيسُدُّ', 'فمه'] ['إِلى', 'وجارُها', 'فيسُدّ', 'فمه']
# correct:  ['وبضمتينِ', 'الحياةُ', 'أعْمارٌ', 'وبالضم'] ['وبضمتينِ', 'الحياةُ', 'أعْمارٌ', 'وبالضم']
# incorrect:  ['المَسجِدُ', 'والبِيعَةُ', 'والكَنيسَةُ', 'وبالفتح'] ['المسجِد', 'والبِيعَةُ', 'والكَنيسَةُ', 'وبالفتح']
# incorrect:  ['الدِّينُ', 'قيلَ', 'ومنه', 'لَعَمْرِي'] ['الدّينُ', 'قيل', 'ومنه', 'لَعَمْري']
# incorrect:  ['الأَسْنان', 'أو', 'لَحْمُ', 'اللِّثَةِ'] ['الأَسْنان', 'أَو', 'لَحْمُ', 'اللّثَةِ']
# incorrect:  ['ويضمُّ', 'عُمُورٌ', 'والشَّنْفُ', 'وكلُّ'] ['ويضمّ', 'عُمُورٌ', 'والشّنْفُ', 'وكلّ']
# incorrect:  ['مُسْتَطِيلٍ', 'بينَ', 'سِنَّتَيْنِ', 'والشَّجَرُ'] ['مُسْتَطِيلٍ', 'بيّنُ', 'سِنّتَيْنِ', 'والشّجَرُ']
# incorrect:  ['الطِّوالُ', 'ونَخْلُ', 'السُّكَّرِ', 'والضمُّ'] ['الطّوالُ', 'ونَخْلُ', 'السّكّرِ', 'والضمّ']
# incorrect:  ['أعْلَى', 'وهي', 'تَمْرٌ', 'جَيِّدٌ'] ['أَعْلَى', 'وهي', 'تَمْرٌ', 'جَيّدٌ']
# incorrect:  ['والعَمْرِيُّ', 'بالفتح', 'تَمْرٌ', 'آخَرُ'] ['والعَمْرِيّ', 'بالفتح', 'تَمْرٌ', 'آخر']
# incorrect:  ['وعَمْرَ', 'اللهِ', 'ما', 'فَعَلْتَ'] ['وعُمْرٌ', 'اللهُ', 'ما', 'فَعَلْتَ']
# incorrect:  ['فَعَلْتَ', 'كذا', 'أصْلُهُ', 'عَمَّرْتُكَ'] ['فَعَلْتَ', 'كذا', 'أَصْلُهُ', 'عَمّرْتُكَ']
# incorrect:  ['اللّهَ', 'تَعْميراً', 'وأُعَمِّرُكَ', 'اللّهَ'] ['اللهُ', 'تَعْميراً', 'وأُعَمّرُكَ', 'اللهُ']
# incorrect:  ['أن', 'تَفْعَلَ', 'تُحَلِّفُهُ', 'باللهِ'] ['أَن', 'تَفْعَلَ', 'تحلّته', 'بالله']
# incorrect:  ['وتَسْألُهُ', 'بِطولِ', 'عُمْرِهِ', 'أو'] ['وتَسأَله', 'بِطولِ', 'عُمْرِه', 'أَو']
# incorrect:  ['لَعَمْرُ', 'اللهِ', 'أي', 'وبقاءِ'] ['لَعَمْرُ', 'اللهُ', 'أَي', 'وبقاءُ']
# incorrect:  ['اللهِ', 'فإذا', 'سَقطَ', 'اللامُ'] ['اللهُ', 'فإِذا', 'سَقَطَ', 'اللام']
# incorrect:  ['نُصِبَ', 'انْتِصابَ', 'المَصادِرِ', 'أو'] ['نصَبَ', 'انْتِصابَ', 'المَصادِرِ', 'أَو']
# incorrect:  ['عَمْرَكَ', 'اللّهَ', 'أي', 'أُذَكِّرُكَ'] ['عمْرك', 'اللهُ', 'أَي', 'أُذكّرُكَ']
# incorrect:  ['اللّهَ', 'تَذْكيراًوجاءَ', 'في', 'الحديثِ'] ['اللهُ', 'تَذْكيراًوجاءَ', 'في', 'الحديث']
# incorrect:  ['النَّهْيُ', 'عن', 'قولِ', 'لَعَمْرُ'] ['النّهْيُ', 'عن', 'قول', 'لَعَمْرُ']
# incorrect:  ['اللهِ', 'وعَمِرَ', 'كفَرِحَ', 'ونَصَرَ'] ['اللهُ', 'وعُمْرٌ', 'كفَرِحَ', 'ونَصَرَ']
# incorrect:  ['وضَرَبَ', 'عَمْراً', 'وعَمَارَةً', 'بَقِيَ'] ['وضَرَبَ', 'عَمْراً', 'وعُمارَةَ', 'بَقيَ']
# incorrect:  ['زَماناً', 'وعَمَرَهُ', 'اللّهُ', 'وعَمَّرَهُ'] ['زَماناً', 'وعُمّرُهُ', 'اللهُ', 'وعُمّرُهُ']
# incorrect:  ['أبْقاهُ', 'وعَمَّرَ', 'نَفْسَهُ', 'قَدَّرَ'] ['أَبْقاه', 'وعُمْرٌ', 'نَفْسُه', 'قدّرَ']
# incorrect:  ['لها', 'قَدْراً', 'مَحْدوداً', 'والعُمْرَى'] ['لها', 'قِدَراً', 'مَحْدوداً', 'والعُمْرَى']
# incorrect:  ['عُمُرِكَ', 'أو', 'عُمُرِهِ', 'وعَمَرْتُه'] ['عمْرك', 'أَو', 'عُمْرِه', 'وعُمْرته']
# incorrect:  ['إياهُ', 'وأعْمَرْتُهُ', 'جَعَلْتُه', 'له'] ['إِياه', 'وأعْمَرْته', 'جعَلْته', 'له']
# incorrect:  ['عُمْرَهُ', 'أو', 'عُمْرِي', 'وعُمْرِيُّ'] ['عُمْرِه', 'أَو', 'عُمْرِي', 'وعُمْرِيّ']
# incorrect:  ['الشَّجَرِ', 'قدِيمُهُ', 'أو', 'السِّدْرُ'] ['الشّجرِ', 'قدِيمُه', 'أَو', 'السّدْرُ']
# incorrect:  ['يَنْبُتُ', 'على', 'الأَنْهارِ', 'وعَمَرَ'] ['يَنْبُتُ', 'على', 'الأَنْهار', 'وعُمْرٌ']
# incorrect:  ['اللّهُ', 'مَنْزِلَكَ', 'عِمارَةً', 'وأعْمَرَهُ'] ['اللهُ', 'منزِلَكَ', 'عِمارةً', 'وأعْمَره']
# incorrect:  ['جَعَلَهُ', 'آهلاً', 'الرجلُ', 'مالَهُ'] ['جعلَه', 'آهلاً', 'الرجلُ', 'مالَه']
# incorrect:  ['وبَيْتَهُ', 'عِمارَةً', 'وعُمُوراً', 'لَزِمَهُ'] ['وبَيتَه', 'عِمارةً', 'وعُمُوراً', 'لَزِمَه']
# incorrect:  ['وعَمَرَ', 'المالُ', 'نَفْسُهُ', 'كنَصَرَ'] ['وعُمْرٌ', 'المال', 'نَفْسُه', 'كنَصَرَ']
# incorrect:  ['وكرُمَ', 'وسَمِعَ', 'عَمارَةً', 'صارَ'] ['وكرُمَ', 'وسَمِعَ', 'عِمارةً', 'صار']
# incorrect:  ['عامِراً', 'وأعْمَرَهُ', 'المكانَ', 'واسْتَعْمَرَهُ'] ['عامِراً', 'وأعْمَره', 'المكانَ', 'واسْتَعْمَرَهُ']
# incorrect:  ['فيه', 'جَعَلَهُ', 'يَعْمُرُهُ', 'والمَعْمَرُ'] ['فيه', 'جعلَه', 'يَعْمُرُه', 'والمَعْمَرُ']
# incorrect:  ['كَمسْكَنٍ', 'المَنْزِلُ', 'الكثيرُ', 'الماءِ'] ['كَمسْكَنٍ', 'المَنْزِلُ', 'الكثيرُ', 'الماءُ']
# incorrect:  ['والكَلأِ', 'وأعْمَرَ', 'الأرضَ', 'وجَدَها'] ['والكَلأِ', 'وأعْمَرٌ', 'الأَرض', 'وجَدَها']
# incorrect:  ['عامِرَةً', 'عليه', 'أغْناهُ', 'والعِمارَةُ'] ['عامِرَةً', 'عليه', 'أَغْناه', 'والعَمارة']
# incorrect:  ['عمامَةٍ', 'وقَلَنْسُوَةٍ', 'وتاجٍ', 'وغيرِهِ'] ['عمامَة', 'وقَلَنْسُوَةٍ', 'وتاجٍ', 'وغيرُهِ']
# incorrect:  ['كالعَمْرَةِ', 'وقد', 'اعْتَمَرَ', 'والعُمْرَةُ'] ['كالعَمْرة', 'وقد', 'اعتمر', 'والعُمْرةُ']
# incorrect:  ['الزيارَةُ', 'وقد', 'اعْتَمَرَ', 'وأعْمَرَهُ'] ['الزيارَةُ', 'وقد', 'اعتمر', 'وأعْمَره']
# incorrect:  ['يَبْنِيَ', 'الرَّجُلُ', 'على', 'امرأتِهِ'] ['يَبْنِيَ', 'الرجلُ', 'على', 'امرأَته']
# incorrect:  ['النَّظْمُ', 'وبها', 'سُمّيَت', 'المرأةُ'] ['النّظْم', 'وبها', 'سمّيت', 'المرأَة']
# incorrect:  ['والمُعْتَمِرُ', 'الزائرُ', 'والقاصِدُ', 'للشيءِ'] ['والمُعْتَمِرُ', 'الزائرُ', 'والقاصِدُ', 'للشيء']
# incorrect:  ['والعَمارَةُ', 'أصْغَرُ', 'من', 'القَبيلَةِ'] ['والعَمارة', 'أَصغر', 'من', 'القَبَيلَةِ']
# incorrect:  ['ويكسرُ', 'أو', 'الحَيُّ', 'العظيمُ'] ['ويكْسَرُ', 'أَو', 'الحيّ', 'العظيم']
# incorrect:  ['ورُقْعَةٌ', 'مُزَيَّنَةٌ', 'تُخاطُ', 'في'] ['ورُقْعَةٌ', 'مُزَيّنَةٌ', 'تُخاطُ', 'في']
# incorrect:  ['المِظَلَّةِ', 'والتَّحِيَّةُ', 'كالعَمارِ', 'والعَمارُ'] ['المِظَلّةِ', 'والتّحِيّةُ', 'كالعَمار', 'والعَمّار']
# incorrect:  ['الرَّيْحانُ', 'يُزَيَّنُ', 'به', 'مَجْلِسُ'] ['الرّيْحانُ', 'يُزَيّنُ', 'به', 'مَجْلِسُ']
# incorrect:  ['الشَّرابِ', 'وعَمَرَ', 'رَبَّهُ', 'عَبَدَهُ'] ['الشّرابِ', 'وعُمْرٌ', 'ربّه', 'عبَدَه']
# incorrect:  ['وصلَّى', 'وصامَ', 'والعَوْمَرَةُ', 'الاختلاطُ'] ['وصلّى', 'وصام', 'والعَوْمَرة', 'الاختلاطُ']
# incorrect:  ['والجَلَبَةُ', 'وجَمْعُ', 'الناسِ', 'وحَبْسُهُم'] ['والجبَة', 'وجَمْعُ', 'الناسُ', 'وحَبْسُهم']
# incorrect:  ['في', 'مكانٍ', 'والعُمَيْرانِ', 'والعَمْرَتانِ'] ['في', 'مكانَ', 'والعُمَيْرانِ', 'والعَمْرتانِ']
# incorrect:  ['والعُمَيرتانِ', 'عَظْمانِ', 'صَغيرانِ', 'في'] ['والعُمَيرتانِ', 'عِظْمانِ', 'صَغيرانِ', 'في']
# incorrect:  ['أصلِ', 'اللسانِ', 'لَهما', 'شُعْبَتانِ'] ['أَصل', 'اللسانِ', 'لهما', 'شُعْبَتانِ']
# correct:  ['يَكْتَنِفانِ', 'الغَلْصَمَةَ', 'من', 'باطنٍ'] ['يَكْتَنِفانِ', 'الغَلْصَمَةَ', 'من', 'باطنٍ']
# incorrect:  ['واليَعْمورُ', 'الجَدْيُ', 'وبهاءٍ', 'شَجَرَةٌ'] ['واليَعْمورُ', 'الجَدْيُ', 'وبهاءٍ', 'شَجَرةٌ']
# incorrect:  ['يَعاميرُ', 'والعَمْرانِ', 'طَرَفَا', 'الكُمَّيْنِ'] ['يَعاميرُ', 'والعُمْرانِ', 'طَرَفَا', 'الكُمّيْنِ']
# incorrect:  ['وعَميرَةُ', 'كسَفينَةٍ', 'أبو', 'بَطْنٍ'] ['وعُميرة', 'كفيفة', 'أَبو', 'بَطْنَ']
# incorrect:  ['وكُوَّارَةُ', 'النَّحْلِ', 'وعَمْرٌو', 'اسْمٌ'] ['وكُوّارة', 'النّحْلِ', 'وعمْرٌو', 'اسمٌ']
# incorrect:  ['أعْمُرٌ', 'وعُمُورٌ', 'واسمُ', 'شَيْطانِ'] ['أُعْمَر', 'وعُمُورٌ', 'واسمُ', 'شَيْطانٍ']
# incorrect:  ['الفَرَزْدَق', 'وعامِرٌ', 'اسمٌ', 'وقد'] ['الفرزدَق', 'وعامرٌ', 'اسمٌ', 'وقد']
# incorrect:  ['يُسَمَّى', 'به', 'الحَيُّ', 'وعُمَرُ'] ['يُسمّى', 'به', 'الحيّ', 'وعُمْرٌ']
# incorrect:  ['وعُوَيْمِرٌ', 'وعَمَّارٌ', 'ومَعْمَرٌ', 'وعِمْرانُ'] ['وعُوَيْمِرٌ', 'وعِمّارٌ', 'ومَعْمَرٌ', 'وعِمْرانُ']
# incorrect:  ['وعُمارَةُ', 'ويَعْمَرُ', 'كيَفْعَلُ', 'أسْماءٌ'] ['وعُمارَةَ', 'ويَعْمَرُ', 'كيَفْعَلُ', 'أَسْماءُ']
# incorrect:  ['والعَمْرانِ', 'عَمْرُو', 'بنُ', 'جابِرٍ'] ['والعُمْرانِ', 'عمْرٌو', 'بن', 'جابِ']
# incorrect:  ['وبَدْرُ', 'بنُ', 'عَمْرٍو', 'واللَّحْمَتانِ'] ['وبَدْرُ', 'بن', 'عمْرٌو', 'واللّحْمَتانِ']
# incorrect:  ['على', 'اللَّهاةِ', 'والعَامِرانِ', 'ابنُ'] ['على', 'اللهاة', 'والعامِران', 'ابن']
# incorrect:  ['مالِكٍ', 'وابنُ', 'الطُّفَيْلِ', 'والعُمَرانِ'] ['مالُك', 'وابنَ', 'الطّفَيْلِ', 'والعُمْرانِ']
# incorrect:  ['عُمَرُ', 'وعُمَرُ', 'بنُ', 'عبدِ'] ['عمر', 'وعُمْرٌ', 'بن', 'عبد']
# incorrect:  ['العَزيزِ', 'وعَمْرَوَيْهِ', 'أعْجَمِيٌّ', 'وأبو'] ['العزيز', 'وعَمْرَوَيْهِ', 'أَعجمي', 'وأَبو']
# incorrect:  ['عَمْرَةَ', 'كُنْيَةُ', 'الإِفلاسِ', 'والجُوعِ'] ['عَمْرة', 'كُنْية', 'الإِفلاسِ', 'والجوْع']
# incorrect:  ['بِقَومٍ', 'حَلَّ', 'بِهِم', 'البلاءُ'] ['بِقَومٍ', 'حَلّ', 'بِهم', 'البلاءُ']
# incorrect:  ['من', 'القَتْلِ', 'ابنِ', 'عُمارَةَ'] ['من', 'القتلُ', 'ابن', 'عِمارةً']
# incorrect:  ['كثُمامَةٍ', 'بأرضِ', 'فارِسَ', 'ماءٌ'] ['كثُمامَةٍ', 'بأَرْضٍ', 'فارِسُ', 'ماءُ']
# incorrect:  ['قُطْرُبٍ', 'وخُطِّئَ', 'وأمُّ', 'عَمْرٍو'] ['قطْرُب', 'وخُطّئَ', 'وأُمّ', 'عمْرٌو']
# incorrect:  ['وأمُّ', 'عامِرٍ', 'الضَّبُعُ', 'والعامِرُ'] ['وأُمّ', 'عامرٌ', 'الضّبُع', 'والعامِرُ']
# incorrect:  ['جِرْوُها', 'والعَمَّارُ', 'الكثيرُ', 'الصلاةِ'] ['جِرْوُها', 'والعَمّار', 'الكثيرُ', 'الصلاةِ']
# incorrect:  ['والصيامِ', 'والقَوِيُّ', 'الإِيمانِ', 'الثابتُ'] ['والصيامِ', 'والقَوِيّ', 'الإِيمان', 'الثابتُ']
# incorrect:  ['في', 'أمرِهِ', 'والطَّيِّبُ', 'الثَّناءِ'] ['في', 'أَمْره', 'والطّيّب', 'الثّناء']
# incorrect:  ['والطَّيِّبُ', 'الرَّوائِحِ', 'والمُجْتَمِعُ', 'الأمر'] ['والطّيّب', 'الرّوائِحِ', 'والمُجْتَمِعُ', 'الأَمر']
# correct:  ['اللازمُ', 'للجماعةِ', 'الحَدِبُ', 'على'] ['اللازمُ', 'للجماعةِ', 'الحَدِبُ', 'على']
# incorrect:  ['السُّلطانِ', 'والحَليمُ', 'الوَقُورُ', 'في'] ['السّلطانِ', 'والحَليمُ', 'الوَقُورُ', 'في']
# incorrect:  ['كلامِهِ', 'والرَّجُلُ', 'يَجْمَعُ', 'أهلَ'] ['كلامِه', 'والرّجلُ', 'يُجْمعُ', 'أَهلُ']
# incorrect:  ['بَيْتِهِ', 'وأصحابَهُ', 'على', 'أدَبِ'] ['بَيْتِهِ', 'وأَصحابه', 'على', 'أَدَب']
# incorrect:  ['وعَمُّورِيَّةُ', 'مُشَدَّدَةَ', 'الميم', 'بالرُّومِ'] ['وعَمّوريّة', 'مُشَدّدَةَ', 'الميم', 'بالرّومِ']
# incorrect:  ['والتَّعْميرُ', 'جَوْدَةُ', 'النَّسْجِ', 'وغَزْلِهِ'] ['والتّعميرُ', 'جَوْدَة', 'النسْجِ', 'وغَزْلِهِ']
# incorrect:  ['والعَمَّارَةُ', 'ماءَةٌ', 'جاهِلِيَّةٌ', 'وبِئْرٌ'] ['والعَمارة', 'ماءَةٌ', 'جاهِلِيّةٌ', 'وبِئْرُ']
# incorrect:  ['بِمِنًى', 'ماءَةٌ', 'بالسَّليلةِ', 'والعِمْرانِيةُ'] ['بِمِنًى', 'ماءَةٌ', 'بالسّليلةِ', 'والعِمْرانِي']
# incorrect:  ['بالكسر', 'قَلْعَةٌ', 'شَرْقِيَّ', 'المَوْصِلِ'] ['بالكسر', 'قَلْعَةٌ', 'شَرْقِيّ', 'المَوْصِلِ']
# incorrect:  ['والعَمْرِيَّةُ', 'ماءٌ', 'بِنَجْدٍ', 'والعُمَرِيَّةُ'] ['والعَمْرِيّة', 'ماءُ', 'بِنَجْدٍ', 'والعَمْرِيّة']
# incorrect:  ['مَحَلَّةٌ', 'ببَغدادَ', 'وبُسْتانُ', 'ابنِ'] ['مَحَلّة', 'ببَغدادَ', 'وبُسْتانُ', 'ابن']
# incorrect:  ['عامرٍ', 'بِنَخْلَةَ', 'ولا', 'تَقُلِ'] ['عامرٌ', 'بِنَخْلَةَ', 'ولا', 'تَقُلِ']
# incorrect:  ['ابنِ', 'مَعْمَرٍ', 'محركةً', 'وعُمْرُ'] ['ابن', 'مَعْمَرٍ', 'محرّكةً', 'وعُمْرٌ']
# incorrect:  ['الزَّعْفَرانِ', 'بالضم', 'بالجَزيرةِ', 'وعُمَّرٌ'] ['الزّعْفَران', 'بالضم', 'بالجَزيرة', 'وعُمْرٌ']
# incorrect:  ['كسُكَّرٍ', 'قُرْبَ', 'واسِطَ', 'وعُمْرُ'] ['كسُكّرٍ', 'قُرْبَ', 'واسِطَ', 'وعُمْرٌ']
# incorrect:  ['نَصْرٍ', 'بِسُرَّ', 'مَنْ', 'رَأى'] ['نُصْرٍ', 'بِسُرّ', 'من', 'رأَى']
# incorrect:  ['والعُمَيْرُ', 'كزُبَيْرٍ', 'قُرْبَ', 'مكةَ'] ['والعَمُيْرُ', 'كزُبَيْرٍ', 'قُرْبَ', 'مكة']
# incorrect:  ['وبِئْرُ', 'عُمَيرٍ', 'في', 'حَزْمِ'] ['وبِئْرُ', 'عَمِيْر', 'في', 'حَزْمِ']
# incorrect:  ['بَني', 'عُوَالٍ', 'والعُمَيْرُ', 'فرسُ'] ['بنِي', 'عُوَالٍ', 'والعَمُيْرُ', 'فَرسُ']
# incorrect:  ['حَنْظَلَةَ', 'ابنِ', 'سَيَّارٍ', 'وأبو'] ['حَنْظَلةَ', 'ابن', 'سَيّارٍ', 'وأَبو']
# incorrect:  ['عُمَيْرٍ', 'كُنْيَةُ', 'الذَّكَرِ', 'وجَلْدُ'] ['عَمِيْر', 'كُنْية', 'الذّكَرِ', 'وجِلْدُ']
# incorrect:  ['عُمَيْرَةَ', 'كنايَةٌ', 'عن', 'الاسْتِمْناء'] ['عَمِيرة', 'كنايَةٌ', 'عن', 'الاستسماء']
# incorrect:  ['باليَدِ', 'والعَمارِيُّ', 'بالفتح', 'سَيْفُ'] ['باليَدِ', 'والعَماريّ', 'بالفتح', 'سَيْفُ']
# incorrect:  ['أبْرَهَةَ', 'بنِ', 'الصَّبَّاحِ', 'والعَمَرُ'] ['أَبْرَهى', 'بن', 'الصّبّاحِ', 'والعَمْرُ']
# incorrect:  ['محركةً', 'المِنْديلُ', 'تُغطِّي', 'به'] ['محرّكةً', 'المِنْديلُ', 'تُغَطّي', 'به']
# incorrect:  ['ولا', 'صَوْقَعَةٌ', 'تُغَطِّي', 'رأسَها'] ['ولا', 'صَوْقَعَة', 'تُغَطّي', 'رأْسها']
# incorrect:  ['فَتُدْخِلُ', 'رأسَها', 'في', 'كُمِّها'] ['فَتُدْخِلُ', 'رأْسها', 'في', 'كُمّها']
# incorrect:  ['وجبلٌ', 'يَصُبُّ', 'في', 'مَسِيلِ'] ['وجبلٌ', 'يصُبّ', 'في', 'مَسِيلِ']
# incorrect:  ['مكةَ', 'وثَوْبٌ', 'عَمِيرٌ', 'صَفيقٌوكثيرٌ'] ['مكة', 'وثَوْبٌ', 'عَمِيْر', 'صَفيقٌوكثيرٌ']
# incorrect:  ['بَجِيرٌ', 'عَمِيرٌ', 'إِتْباعٌ', 'والبيتُ'] ['بَجِير', 'عَمِيْر', 'إِتْباعٌ', 'والبيتُ']
# incorrect:  ['المَعْمورُ', 'في', 'السماءِ', 'بإِزاءِ'] ['المَعْمورُ', 'في', 'السماء', 'بإِزاء']
# incorrect:  ['الكعبةِ', 'شَرَّفَها', 'اللّهُ', 'تعالى'] ['الكعبةِ', 'شَرّفَها', 'اللهُ', 'تعالى']
# incorrect:  ['كيف', 'يلتقيانِأيُّها', 'المنْكِحُ', 'الثُرَيّا'] ['كيفٍ', 'يلتقيانِأيّها', 'المنْكِحُ', 'الثُرَيّا']
# incorrect:  ['الخرابَ', 'أعْمُرُهُ', 'عِمارَةً', 'فهو'] ['الخرابَ', 'أَعْمُره', 'عِمارةً', 'فهو']
# incorrect:  ['ماءٍ', 'دافقٍ', 'أي', 'مدفوقٍ'] ['ماءُ', 'دافقٍ', 'أَي', 'مدفوقٍ']
# incorrect:  ['وعيشةٍ', 'راضيةٍ', 'أي', 'أيضاً'] ['وعيشةٍ', 'راضيةٍ', 'أَي', 'أَيضاً']
# incorrect:  ['عَروضٌ', 'إليها', 'يَلْجَؤونَ', 'وجانِبِلِكلِّ'] ['عَروّضٌ', 'إِليها', 'يَلْجَؤونَ', 'وجانِبِلِكلّ']
# incorrect:  ['أُناسٍ', 'من', 'مَعَدٍّ', 'عِـمـارةٍ'] ['أُناسٌ', 'من', 'مَعَدّ', 'عِـمـارةٍ']
# incorrect:  ['وجَلَبَة', 'وأعْمَرْتُهُ', 'داراً', 'أو'] ['وجَلَبَة', 'وأعْمَرْته', 'داراً', 'أَو']
# incorrect:  ['فإذا', 'متَّ', 'رجعتْ', 'إليَّ'] ['فإِذا', 'متّ', 'رجعتْ', 'إِليّ']
# incorrect:  ['إلا', 'مُعْمَـراتٌ', 'ودائِعُوما', 'البرُّ'] ['إِلا', 'مُعْمَـراتٌ', 'ودائِعُوما', 'البرّ']
# incorrect:  ['ورَفَعنا', 'العَمارافلمَّا', 'أتانا', 'بُعَيْدَ'] ['ورَفَعنا', 'العامرفلاا', 'أَتانا', 'بُعيد']
# incorrect:  ['من', 'تَثْليثَ', 'النفسُ', 'لمَّا'] ['من', 'تَثْليثَ', 'النفس', 'لمّا']
# incorrect:  ['جاء', 'فَلُّهُـمُ', 'فإنَّ', 'الأصمعيّ'] ['جاء', 'فَلّهُـمُ', 'فإِن', 'الأَصمعي']
# incorrect:  ['كما', 'يُهِلُّ', 'الراكبُ', 'بالفَرْقَدِ'] ['كما', 'يُهلّ', 'الراكب', 'بالفَرْقد']
# incorrect:  ['لكِ', 'من', 'قُبَّرَةٍ', 'بمَعْمَرِ'] ['لَكَ', 'من', 'قُبّرَةٍ', 'بمَعْمَرِ']
# incorrect:  ['أُذكِّركَ', 'اللهَ', 'تحلِّفه', 'بالله'] ['أُذكّرُكَ', 'اللهُ', 'تحلّته', 'بالله']
# incorrect:  ['الناسُ', 'طالت', 'أعمارُهم', 'وَعَمَّرَهم'] ['الناسُ', 'طالت', 'أَعمارهم', 'وعَمّرَهم']
# incorrect:  ['الله', 'جلّ', 'ثناؤُه', 'تعميراًومن'] ['اللهُ', 'جلّ', 'ثناؤُه', 'تعميراًومن']
# incorrect:  ['عَمَرَ', 'الناسُ', 'الأرضَ', 'عِمارةً'] ['عمر', 'الناسُ', 'الأَرض', 'عِمارةً']
# incorrect:  ['عُمِرتوالاسم', 'والمصدر', 'العُمْران', 'واستَعمر'] ['عمِرتوالاسم', 'والمصدر', 'العمْران', 'واستَعمر']
# incorrect:  ['هذاوأمّا', 'الآخر', 'فالعَوْمَرة', 'الصِّياح'] ['هذاوأمّا', 'الآخر', 'فالعَوْمَرة', 'الصّياح']
# incorrect:  ['والجلَبةويقال', 'اعتَمَرَ', 'الرّجُل', 'إذا'] ['والجلَبةويقال', 'اعتمر', 'الرجلُ', 'إِذا']
# incorrect:  ['أهَلَّ', 'بعُمرته', 'وذلك', 'رفْعُه'] ['أَهلُ', 'بعمرته', 'وذلك', 'رفعه']
# incorrect:  ['صوتَه', 'بالتَّلبية', 'للعُمرة', 'فأمّا'] ['صوتَه', 'بالتّلبية', 'للعُمرة', 'فأَمّا']
# incorrect:  ['بالفَرقد', 'رُكبانُهاكما', 'يُهلُّ', 'الراكب'] ['بالفَرْقد', 'رُكبانُهاكما', 'يُهلّ', 'الراكب']
# incorrect:  ['أهلُ', 'اللغة', 'والعَمَار', 'كلُّ'] ['أَهلُ', 'اللغة', 'والعَمّار', 'كلّ']
# incorrect:  ['أيضاً', 'قال', 'ابنُ', 'السِّكِّيت'] ['أَيضاً', 'قال', 'ابن', 'السكيت']
# incorrect:  ['العَمَار', 'التَّحيَّة', 'يقال', 'عمَّرك'] ['العَمَار', 'التّحيّة', 'يقال', 'عمْرك']
# incorrect:  ['والعُرُّ', 'والعُرَّةُ', 'الجربُ', 'وقيل'] ['والعُرّ', 'والعُرّةُ', 'الجربِ', 'وقيل']
# incorrect:  ['قُروحٌ', 'بأَعناق', 'الفُصلان', 'يقال'] ['قُروحٌ', 'بأَعناق', 'الفُصْلان', 'يقال']
# incorrect:  ['الشاعر', 'ولانَ', 'جِلْدُ', 'الأَرضِ'] ['الشاعر', 'ولانَ', 'جِلْدِ', 'الأَرض']
# incorrect:  ['بعد', 'عَرِّه', 'أَي', 'جَرَبِه'] ['بعد', 'عرّه', 'أَي', 'جَرَبِه']
# incorrect:  ['وقيل', 'العُرُّ', 'داءٌ', 'يأْخذ'] ['وقيل', 'العَرّ', 'داءٌ', 'يأُخُذ']
# accuracy of words: 0.48031496062992124 671 726
# percentage correct diacritic: 1.0
# Number of all words:  1342
# accuracy of sentence: 0.10141509433962265 43 381
# Number of all sentences:  424
